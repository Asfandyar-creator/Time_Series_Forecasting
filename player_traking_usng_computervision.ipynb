# %%
# !pip install ultralytics
# !pip install supervision
# !pip install opencv-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.54-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.1/800.1 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 58.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 ultralytics-8.2.54 ultralytics-thop-2.0.0
# Collecting supervision
#   Downloading supervision-0.21.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.0/124.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from supervision) (3.7.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from supervision) (1.25.2)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in /usr/local/lib/python3.10/dist-packages (from supervision) (4.10.0.84)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.10/dist-packages (from supervision) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from supervision) (6.0.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from supervision) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.16.0)
# Installing collected packages: supervision
# Successfully installed supervision-0.21.0
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.25.2)

# %%
#**********************************LIBRARIES*********************************#
from ultralytics import YOLO
import supervision as sv
import pickle
import os
import cv2

# INPUT-video file
video_path = 'video_input.mp4'
# OUTPUT-Video File
output_video_path = 'output_video.mp4'
# PICKLE FILE (IF AVAILABLE LOADS IT IF NOT, SAVES IT IN THIS PATH)
pickle_path = 'track_stubs.pkl'

# %%
#*********************************TRACKING MECHANISM**************************#
class HockeyAnalyzer:
    def __init__(self, model_path):
        self.model = YOLO(model_path)
        self.tracker = sv.ByteTrack()

    def detect_frames(self, frames):
        batch_size = 20
        detections = []
        for i in range(0, len(frames), batch_size):
            detections_batch = self.model.predict(frames[i:i+batch_size], conf=0.1)
            detections += detections_batch
        return detections

#********LOAD TRACKS FROM FILE OR DETECT OBJECTS-SAVES PICKLE FILE************#

    def get_object_tracks(self, frames, read_from_stub=False, stub_path=None):
        if read_from_stub and stub_path is not None and os.path.exists(stub_path):
            with open(stub_path, 'rb') as f:
                tracks = pickle.load(f)
            return tracks

        detections = self.detect_frames(frames)

        tracks = {"person": []}

        for frame_num, detection in enumerate(detections):
            cls_names = detection.names
            cls_names_inv = {v: k for k, v in cls_names.items()}

            # Tracking Mechanism
            detection_supervision = sv.Detections.from_ultralytics(detection)
            detection_with_tracks = self.tracker.update_with_detections(detection_supervision)
            tracks["person"].append({})

            for frame_detection in detection_with_tracks:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]
                track_id = frame_detection[4]

                if cls_id == cls_names_inv.get('person', None):
                    tracks["person"][frame_num][track_id] = {"bbox": bbox}

            for frame_detection in detection_supervision:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]

        if stub_path is not None:
            with open(stub_path, 'wb') as f:
                pickle.dump(tracks, f)

        return tracks

#***********************BOUNDING BOXES AND TRACK-IDs**************************#

    def draw_annotations(self, video_frames, tracks):
        output_video_frames = []
        for frame_num, frame in enumerate(video_frames):
            frame = frame.copy()
            player_dict = tracks["person"][frame_num]

            # Draw Players
            for track_id, player in player_dict.items():
                color = player.get("team_color", (0, 0, 255))
                bbox = player["bbox"]
                x1, y1, x2, y2 = map(int, bbox)
            # Bounding boxes
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            # Track_id
                cv2.putText(frame, str(track_id), (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

            output_video_frames.append(frame)

        return output_video_frames

# %%
#*************** EXECUTES TRACKING MECHANISM AND OUTPUT VIDEO****************#

# Read the video frames
video_frames = []
cap = cv2.VideoCapture(video_path)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    video_frames.append(frame)
cap.release()

#********************* EXECUTE TRACKING METHOD WITH YOLO**********************#
tracker = HockeyAnalyzer('yolov8x.pt')
tracks = tracker.get_object_tracks(video_frames, read_from_stub=True, stub_path=pickle_path)
annotated_frames = tracker.draw_annotations(video_frames, tracks)

#*********************** SAVES VIDEO FILE ************************************#
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
height, width, _ = annotated_frames[0].shape
out = cv2.VideoWriter(output_video_path, fourcc, 30, (width, height))

for frame in annotated_frames:
    out.write(frame)
out.release()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8x.pt to 'yolov8x.pt'...
# 100%|██████████| 131M/131M [00:00<00:00, 194MB/s]
# 0: 384x640 28 persons, 3233.6ms
# 1: 384x640 26 persons, 3233.6ms
# 2: 384x640 28 persons, 3233.6ms
# 3: 384x640 28 persons, 3233.6ms
# 4: 384x640 28 persons, 3233.6ms
# 5: 384x640 31 persons, 3233.6ms
# 6: 384x640 27 persons, 3233.6ms
# 7: 384x640 27 persons, 3233.6ms
# 8: 384x640 26 persons, 3233.6ms
# 9: 384x640 28 persons, 3233.6ms
# 10: 384x640 26 persons, 3233.6ms
# 11: 384x640 29 persons, 3233.6ms
# 12: 384x640 27 persons, 3233.6ms
# 13: 384x640 28 persons, 3233.6ms
# 14: 384x640 28 persons, 3233.6ms
# 15: 384x640 31 persons, 2 skiss, 3233.6ms
# 16: 384x640 29 persons, 1 skis, 3233.6ms
# 17: 384x640 28 persons, 1 skis, 3233.6ms
# 18: 384x640 25 persons, 1 skis, 3233.6ms
# 19: 384x640 24 persons, 1 skis, 3233.6ms
# Speed: 9.1ms preprocess, 3233.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 skis, 3155.5ms
# 1: 384x640 26 persons, 2 skiss, 3155.5ms
# 2: 384x640 25 persons, 2 skiss, 3155.5ms
# 3: 384x640 26 persons, 2 skiss, 3155.5ms
# 4: 384x640 29 persons, 2 skiss, 3155.5ms
# 5: 384x640 28 persons, 1 skis, 2 skateboards, 3155.5ms
# 6: 384x640 26 persons, 1 skis, 1 baseball bat, 3155.5ms
# 7: 384x640 26 persons, 1 baseball bat, 2 skateboards, 3155.5ms
# 8: 384x640 26 persons, 1 baseball bat, 1 skateboard, 3155.5ms
# 9: 384x640 28 persons, 1 baseball bat, 3155.5ms
# 10: 384x640 26 persons, 3155.5ms
# 11: 384x640 26 persons, 1 skateboard, 3155.5ms
# 12: 384x640 28 persons, 1 skateboard, 3155.5ms
# 13: 384x640 28 persons, 1 skateboard, 3155.5ms
# 14: 384x640 26 persons, 1 snowboard, 3155.5ms
# 15: 384x640 28 persons, 1 snowboard, 3155.5ms
# 16: 384x640 27 persons, 2 skiss, 1 snowboard, 3155.5ms
# 17: 384x640 25 persons, 1 snowboard, 3155.5ms
# 18: 384x640 27 persons, 2 skiss, 3155.5ms
# 19: 384x640 22 persons, 1 skis, 3155.5ms
# Speed: 4.6ms preprocess, 3155.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 skis, 3085.6ms
# 1: 384x640 26 persons, 1 skis, 3085.6ms
# 2: 384x640 22 persons, 2 skiss, 3085.6ms
# 3: 384x640 23 persons, 1 skis, 3085.6ms
# 4: 384x640 23 persons, 2 skiss, 3085.6ms
# 5: 384x640 26 persons, 2 skiss, 3085.6ms
# 6: 384x640 24 persons, 2 skiss, 3085.6ms
# 7: 384x640 24 persons, 4 skiss, 3085.6ms
# 8: 384x640 25 persons, 3 skiss, 3085.6ms
# 9: 384x640 23 persons, 3 skiss, 3085.6ms
# 10: 384x640 24 persons, 5 skiss, 3085.6ms
# 11: 384x640 25 persons, 2 skiss, 3085.6ms
# 12: 384x640 20 persons, 2 skiss, 1 snowboard, 3085.6ms
# 13: 384x640 20 persons, 4 skiss, 3085.6ms
# 14: 384x640 18 persons, 3 skiss, 3085.6ms
# 15: 384x640 20 persons, 2 skiss, 3085.6ms
# 16: 384x640 20 persons, 5 skiss, 3085.6ms
# 17: 384x640 21 persons, 7 skiss, 3085.6ms
# 18: 384x640 20 persons, 5 skiss, 3085.6ms
# 19: 384x640 21 persons, 5 skiss, 3085.6ms
# Speed: 5.7ms preprocess, 3085.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 6 skiss, 3076.8ms
# 1: 384x640 19 persons, 8 skiss, 3076.8ms
# 2: 384x640 19 persons, 8 skiss, 3076.8ms
# 3: 384x640 19 persons, 7 skiss, 3076.8ms
# 4: 384x640 18 persons, 7 skiss, 3076.8ms
# 5: 384x640 19 persons, 5 skiss, 3076.8ms
# 6: 384x640 19 persons, 3 skiss, 3076.8ms
# 7: 384x640 19 persons, 5 skiss, 3076.8ms
# 8: 384x640 19 persons, 7 skiss, 1 snowboard, 3076.8ms
# 9: 384x640 19 persons, 4 skiss, 1 snowboard, 3076.8ms
# 10: 384x640 21 persons, 5 skiss, 1 snowboard, 3076.8ms
# 11: 384x640 20 persons, 5 skiss, 3076.8ms
# 12: 384x640 22 persons, 5 skiss, 3076.8ms
# 13: 384x640 23 persons, 5 skiss, 3076.8ms
# 14: 384x640 24 persons, 3 skiss, 3076.8ms
# 15: 384x640 23 persons, 4 skiss, 3076.8ms
# 16: 384x640 21 persons, 6 skiss, 3076.8ms
# 17: 384x640 21 persons, 6 skiss, 3076.8ms
# 18: 384x640 19 persons, 5 skiss, 2 snowboards, 3076.8ms
# 19: 384x640 21 persons, 7 skiss, 3076.8ms
# Speed: 7.0ms preprocess, 3076.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 skiss, 3152.6ms
# 1: 384x640 20 persons, 5 skiss, 3152.6ms
# 2: 384x640 21 persons, 3 skiss, 3152.6ms
# 3: 384x640 20 persons, 4 skiss, 3152.6ms
# 4: 384x640 20 persons, 3 skiss, 3152.6ms
# 5: 384x640 20 persons, 1 bench, 1 skis, 3152.6ms
# 6: 384x640 21 persons, 4 skiss, 3152.6ms
# 7: 384x640 22 persons, 2 skiss, 3152.6ms
# 8: 384x640 21 persons, 1 backpack, 2 skiss, 1 snowboard, 2 skateboards, 3152.6ms
# 9: 384x640 22 persons, 1 skis, 3152.6ms
# 10: 384x640 19 persons, 2 skiss, 1 baseball bat, 3152.6ms
# 11: 384x640 21 persons, 2 skiss, 1 skateboard, 3152.6ms
# 12: 384x640 20 persons, 3 skiss, 3152.6ms
# 13: 384x640 19 persons, 2 skiss, 3152.6ms
# 14: 384x640 20 persons, 4 skiss, 3152.6ms
# 15: 384x640 20 persons, 3 skiss, 3152.6ms
# 16: 384x640 20 persons, 8 skiss, 3152.6ms
# 17: 384x640 21 persons, 4 skiss, 1 snowboard, 3152.6ms
# 18: 384x640 22 persons, 4 skiss, 1 snowboard, 3152.6ms
# 19: 384x640 25 persons, 5 skiss, 3152.6ms
# Speed: 4.8ms preprocess, 3152.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 3 skiss, 3138.2ms
# 1: 384x640 22 persons, 3 skiss, 3138.2ms
# 2: 384x640 20 persons, 2 skiss, 3138.2ms
# 3: 384x640 19 persons, 2 skiss, 3138.2ms
# 4: 384x640 22 persons, 2 skiss, 3138.2ms
# 5: 384x640 22 persons, 2 skiss, 3138.2ms
# 6: 384x640 23 persons, 4 skiss, 3138.2ms
# 7: 384x640 23 persons, 3 skiss, 3138.2ms
# 8: 384x640 24 persons, 3 skiss, 3138.2ms
# 9: 384x640 23 persons, 4 skiss, 3138.2ms
# 10: 384x640 22 persons, 2 skiss, 3138.2ms
# 11: 384x640 21 persons, 3 skiss, 3138.2ms
# 12: 384x640 20 persons, 3 skiss, 3138.2ms
# 13: 384x640 22 persons, 5 skiss, 3138.2ms
# 14: 384x640 21 persons, 2 skiss, 3138.2ms
# 15: 384x640 22 persons, 3 skiss, 3138.2ms
# 16: 384x640 21 persons, 6 skiss, 3138.2ms
# 17: 384x640 22 persons, 5 skiss, 3138.2ms
# 18: 384x640 22 persons, 4 skiss, 3138.2ms
# 19: 384x640 23 persons, 4 skiss, 3138.2ms
# Speed: 5.5ms preprocess, 3138.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 3 skiss, 3110.2ms
# 1: 384x640 22 persons, 3 skiss, 3110.2ms
# 2: 384x640 19 persons, 5 skiss, 3110.2ms
# 3: 384x640 18 persons, 4 skiss, 3110.2ms
# 4: 384x640 16 persons, 4 skiss, 3110.2ms
# 5: 384x640 17 persons, 4 skiss, 3110.2ms
# 6: 384x640 18 persons, 5 skiss, 3110.2ms
# 7: 384x640 18 persons, 5 skiss, 3110.2ms
# 8: 384x640 16 persons, 5 skiss, 3110.2ms
# 9: 384x640 19 persons, 5 skiss, 3110.2ms
# 10: 384x640 21 persons, 6 skiss, 3110.2ms
# 11: 384x640 21 persons, 6 skiss, 3110.2ms
# 12: 384x640 19 persons, 7 skiss, 3110.2ms
# 13: 384x640 20 persons, 5 skiss, 3110.2ms
# 14: 384x640 23 persons, 5 skiss, 3110.2ms
# 15: 384x640 24 persons, 5 skiss, 3110.2ms
# 16: 384x640 24 persons, 6 skiss, 3110.2ms
# 17: 384x640 22 persons, 6 skiss, 3110.2ms
# 18: 384x640 21 persons, 4 skiss, 3110.2ms
# 19: 384x640 20 persons, 4 skiss, 3110.2ms
# Speed: 5.5ms preprocess, 3110.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 5 skiss, 3124.4ms
# 1: 384x640 23 persons, 5 skiss, 3124.4ms
# 2: 384x640 18 persons, 3 skiss, 3124.4ms
# 3: 384x640 15 persons, 2 skiss, 3124.4ms
# 4: 384x640 20 persons, 3 skiss, 3124.4ms
# 5: 384x640 22 persons, 4 skiss, 3124.4ms
# 6: 384x640 22 persons, 4 skiss, 3124.4ms
# 7: 384x640 19 persons, 3 skiss, 3124.4ms
# 8: 384x640 21 persons, 4 skiss, 3124.4ms
# 9: 384x640 20 persons, 3 skiss, 3124.4ms
# 10: 384x640 22 persons, 3 skiss, 3124.4ms
# 11: 384x640 20 persons, 3 skiss, 3124.4ms
# 12: 384x640 22 persons, 3 skiss, 3124.4ms
# 13: 384x640 21 persons, 4 skiss, 3124.4ms
# 14: 384x640 20 persons, 2 skiss, 3124.4ms
# 15: 384x640 20 persons, 2 skiss, 3124.4ms
# 16: 384x640 23 persons, 1 skis, 3124.4ms
# 17: 384x640 22 persons, 1 skis, 3124.4ms
# 18: 384x640 23 persons, 1 skis, 3124.4ms
# 19: 384x640 25 persons, 1 skis, 3124.4ms
# Speed: 8.2ms preprocess, 3124.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 3152.1ms
# 1: 384x640 24 persons, 3152.1ms
# 2: 384x640 21 persons, 3152.1ms
# 3: 384x640 20 persons, 1 skis, 3152.1ms
# 4: 384x640 22 persons, 2 skiss, 3152.1ms
# 5: 384x640 22 persons, 2 skiss, 3152.1ms
# 6: 384x640 20 persons, 2 skiss, 3152.1ms
# 7: 384x640 20 persons, 3 skiss, 3152.1ms
# 8: 384x640 20 persons, 3 skiss, 3152.1ms
# 9: 384x640 22 persons, 1 skis, 3152.1ms
# 10: 384x640 20 persons, 1 skis, 3152.1ms
# 11: 384x640 21 persons, 1 skis, 1 skateboard, 3152.1ms
# 12: 384x640 20 persons, 1 skateboard, 3152.1ms
# 13: 384x640 21 persons, 3152.1ms
# 14: 384x640 22 persons, 3152.1ms
# 15: 384x640 21 persons, 1 skateboard, 3152.1ms
# 16: 384x640 21 persons, 3152.1ms
# 17: 384x640 21 persons, 1 skis, 1 skateboard, 3152.1ms
# 18: 384x640 19 persons, 3152.1ms
# 19: 384x640 20 persons, 3152.1ms
# Speed: 4.7ms preprocess, 3152.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 skateboard, 3172.9ms
# 1: 384x640 19 persons, 1 skis, 1 skateboard, 3172.9ms
# 2: 384x640 23 persons, 1 skis, 3172.9ms
# 3: 384x640 19 persons, 1 skis, 1 skateboard, 3172.9ms
# 4: 384x640 21 persons, 1 skis, 1 skateboard, 3172.9ms
# 5: 384x640 21 persons, 1 skis, 3172.9ms
# 6: 384x640 20 persons, 1 skis, 3172.9ms
# 7: 384x640 18 persons, 1 skis, 3172.9ms
# 8: 384x640 18 persons, 1 skis, 3172.9ms
# 9: 384x640 20 persons, 3 skiss, 3172.9ms
# 10: 384x640 18 persons, 2 skiss, 3172.9ms
# 11: 384x640 17 persons, 2 skiss, 3172.9ms
# 12: 384x640 18 persons, 2 skiss, 1 skateboard, 3172.9ms
# 13: 384x640 18 persons, 4 skiss, 1 skateboard, 3172.9ms
# 14: 384x640 16 persons, 6 skiss, 1 skateboard, 3172.9ms
# 15: 384x640 17 persons, 4 skiss, 3172.9ms
# 16: 384x640 17 persons, 4 skiss, 3172.9ms
# 17: 384x640 20 persons, 3 skiss, 3172.9ms
# 18: 384x640 23 persons, 3 skiss, 3172.9ms
# 19: 384x640 20 persons, 5 skiss, 3172.9ms
# Speed: 4.4ms preprocess, 3172.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 5 skiss, 1 skateboard, 3166.3ms
# 1: 384x640 22 persons, 5 skiss, 1 skateboard, 3166.3ms
# 2: 384x640 23 persons, 9 skiss, 1 skateboard, 3166.3ms
# 3: 384x640 24 persons, 9 skiss, 3166.3ms
# 4: 384x640 20 persons, 2 backpacks, 10 skiss, 3166.3ms
# 5: 384x640 21 persons, 1 backpack, 9 skiss, 3166.3ms
# 6: 384x640 24 persons, 9 skiss, 3166.3ms
# 7: 384x640 22 persons, 10 skiss, 1 snowboard, 3166.3ms
# 8: 384x640 21 persons, 7 skiss, 3166.3ms
# 9: 384x640 20 persons, 7 skiss, 1 snowboard, 3166.3ms
# 10: 384x640 20 persons, 9 skiss, 1 skateboard, 3166.3ms
# 11: 384x640 20 persons, 7 skiss, 1 skateboard, 3166.3ms
# 12: 384x640 19 persons, 7 skiss, 1 skateboard, 3166.3ms
# 13: 384x640 19 persons, 7 skiss, 3166.3ms
# 14: 384x640 25 persons, 5 skiss, 3166.3ms
# 15: 384x640 22 persons, 3 skiss, 3166.3ms
# 16: 384x640 22 persons, 5 skiss, 1 skateboard, 3166.3ms
# 17: 384x640 19 persons, 5 skiss, 3166.3ms
# 18: 384x640 21 persons, 4 skiss, 3166.3ms
# 19: 384x640 20 persons, 5 skiss, 1 skateboard, 3166.3ms
# Speed: 4.3ms preprocess, 3166.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 3 skiss, 1 skateboard, 3116.0ms
# 1: 384x640 23 persons, 3 skiss, 3116.0ms
# 2: 384x640 21 persons, 4 skiss, 3116.0ms
# 3: 384x640 21 persons, 4 skiss, 3116.0ms
# 4: 384x640 24 persons, 3 skiss, 3116.0ms
# 5: 384x640 27 persons, 6 skiss, 2 snowboards, 1 sports ball, 3116.0ms
# 6: 384x640 25 persons, 7 skiss, 3116.0ms
# 7: 384x640 21 persons, 6 skiss, 1 snowboard, 3116.0ms
# 8: 384x640 22 persons, 7 skiss, 1 snowboard, 3116.0ms
# 9: 384x640 22 persons, 7 skiss, 1 skateboard, 3116.0ms
# 10: 384x640 21 persons, 8 skiss, 3116.0ms
# 11: 384x640 19 persons, 7 skiss, 3116.0ms
# 12: 384x640 19 persons, 1 backpack, 7 skiss, 3116.0ms
# 13: 384x640 19 persons, 5 skiss, 3116.0ms
# 14: 384x640 20 persons, 8 skiss, 3116.0ms
# 15: 384x640 21 persons, 5 skiss, 3116.0ms
# 16: 384x640 21 persons, 5 skiss, 3116.0ms
# 17: 384x640 20 persons, 4 skiss, 3116.0ms
# 18: 384x640 22 persons, 2 skiss, 1 skateboard, 3116.0ms
# 19: 384x640 20 persons, 2 skiss, 1 skateboard, 3116.0ms
# Speed: 5.4ms preprocess, 3116.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 backpack, 2 skiss, 2 skateboards, 3143.7ms
# 1: 384x640 20 persons, 2 skiss, 1 skateboard, 3143.7ms
# 2: 384x640 19 persons, 2 skiss, 3143.7ms
# 3: 384x640 22 persons, 1 skis, 3143.7ms
# 4: 384x640 22 persons, 1 skis, 3143.7ms
# 5: 384x640 21 persons, 1 skis, 3143.7ms
# 6: 384x640 19 persons, 2 skiss, 1 skateboard, 3143.7ms
# 7: 384x640 19 persons, 3 skiss, 3143.7ms
# 8: 384x640 20 persons, 4 skiss, 3143.7ms
# 9: 384x640 20 persons, 5 skiss, 3143.7ms
# 10: 384x640 19 persons, 3 skiss, 3143.7ms
# 11: 384x640 21 persons, 5 skiss, 1 snowboard, 3143.7ms
# 12: 384x640 19 persons, 6 skiss, 1 snowboard, 1 skateboard, 3143.7ms
# 13: 384x640 17 persons, 7 skiss, 3143.7ms
# 14: 384x640 19 persons, 3 skiss, 1 snowboard, 1 skateboard, 3143.7ms
# 15: 384x640 21 persons, 4 skiss, 2 snowboards, 3143.7ms
# 16: 384x640 23 persons, 4 skiss, 1 snowboard, 3143.7ms
# 17: 384x640 21 persons, 1 backpack, 4 skiss, 3143.7ms
# 18: 384x640 22 persons, 3 backpacks, 3 skiss, 3143.7ms
# 19: 384x640 22 persons, 1 backpack, 6 skiss, 3143.7ms
# Speed: 9.0ms preprocess, 3143.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 skiss, 1 snowboard, 3131.1ms
# 1: 384x640 19 persons, 2 skiss, 1 snowboard, 3131.1ms
# 2: 384x640 22 persons, 4 skiss, 3131.1ms
# 3: 384x640 22 persons, 4 skiss, 3131.1ms
# 4: 384x640 21 persons, 5 skiss, 3131.1ms
# 5: 384x640 22 persons, 5 skiss, 3131.1ms
# 6: 384x640 22 persons, 3 skiss, 3131.1ms
# 7: 384x640 21 persons, 3 skiss, 3131.1ms
# 8: 384x640 20 persons, 3 skiss, 3131.1ms
# 9: 384x640 22 persons, 4 skiss, 3131.1ms
# 10: 384x640 21 persons, 5 skiss, 3131.1ms
# 11: 384x640 20 persons, 5 skiss, 3131.1ms
# 12: 384x640 19 persons, 6 skiss, 3131.1ms
# 13: 384x640 22 persons, 6 skiss, 3131.1ms
# 14: 384x640 23 persons, 6 skiss, 3131.1ms
# 15: 384x640 21 persons, 6 skiss, 3131.1ms
# 16: 384x640 20 persons, 7 skiss, 3131.1ms
# 17: 384x640 19 persons, 4 skiss, 3131.1ms
# 18: 384x640 21 persons, 5 skiss, 3131.1ms
# 19: 384x640 20 persons, 3 skiss, 3131.1ms
# Speed: 4.8ms preprocess, 3131.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 4 skiss, 3172.8ms
# 1: 384x640 20 persons, 3 skiss, 3172.8ms
# 2: 384x640 18 persons, 4 skiss, 3172.8ms
# 3: 384x640 19 persons, 6 skiss, 3172.8ms
# 4: 384x640 18 persons, 7 skiss, 3172.8ms
# 5: 384x640 18 persons, 4 skiss, 3172.8ms
# 6: 384x640 18 persons, 7 skiss, 1 skateboard, 3172.8ms
# 7: 384x640 21 persons, 7 skiss, 3172.8ms
# 8: 384x640 20 persons, 8 skiss, 3172.8ms
# 9: 384x640 19 persons, 6 skiss, 3172.8ms
# 10: 384x640 19 persons, 6 skiss, 3172.8ms
# 11: 384x640 18 persons, 4 skiss, 3172.8ms
# 12: 384x640 18 persons, 5 skiss, 3172.8ms
# 13: 384x640 21 persons, 6 skiss, 3172.8ms
# 14: 384x640 21 persons, 3 skiss, 3172.8ms
# 15: 384x640 21 persons, 4 skiss, 2 skateboards, 3172.8ms
# 16: 384x640 20 persons, 5 skiss, 3172.8ms
# 17: 384x640 18 persons, 6 skiss, 3172.8ms
# 18: 384x640 19 persons, 7 skiss, 3172.8ms
# 19: 384x640 20 persons, 5 skiss, 3172.8ms
# Speed: 4.5ms preprocess, 3172.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 9 skiss, 3134.0ms
# 1: 384x640 21 persons, 9 skiss, 3134.0ms
# 2: 384x640 22 persons, 3 skiss, 1 skateboard, 3134.0ms
# 3: 384x640 20 persons, 7 skiss, 1 snowboard, 3134.0ms
# 4: 384x640 20 persons, 4 skiss, 1 snowboard, 1 skateboard, 3134.0ms
# 5: 384x640 17 persons, 4 skiss, 1 snowboard, 1 skateboard, 3134.0ms
# 6: 384x640 21 persons, 5 skiss, 1 snowboard, 1 skateboard, 3134.0ms
# 7: 384x640 18 persons, 6 skiss, 1 skateboard, 3134.0ms
# 8: 384x640 19 persons, 6 skiss, 3134.0ms
# 9: 384x640 18 persons, 6 skiss, 3134.0ms
# 10: 384x640 16 persons, 7 skiss, 3134.0ms
# 11: 384x640 16 persons, 4 skiss, 1 skateboard, 3134.0ms
# 12: 384x640 18 persons, 4 skiss, 1 snowboard, 3134.0ms
# 13: 384x640 17 persons, 5 skiss, 1 skateboard, 3134.0ms
# 14: 384x640 16 persons, 5 skiss, 1 skateboard, 3134.0ms
# 15: 384x640 20 persons, 4 skiss, 1 skateboard, 3134.0ms
# 16: 384x640 18 persons, 4 skiss, 1 skateboard, 3134.0ms
# 17: 384x640 19 persons, 2 skiss, 3 skateboards, 3134.0ms
# 18: 384x640 19 persons, 2 skiss, 1 baseball bat, 3 skateboards, 3134.0ms
# 19: 384x640 20 persons, 1 skis, 3 skateboards, 3134.0ms
# Speed: 5.1ms preprocess, 3134.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 skis, 3 skateboards, 3104.2ms
# 1: 384x640 18 persons, 2 skiss, 4 skateboards, 3104.2ms
# 2: 384x640 18 persons, 2 skiss, 4 skateboards, 3104.2ms
# 3: 384x640 19 persons, 3 skiss, 4 skateboards, 3104.2ms
# 4: 384x640 16 persons, 3 skiss, 1 skateboard, 3104.2ms
# 5: 384x640 18 persons, 3 skiss, 1 snowboard, 1 skateboard, 3104.2ms
# 6: 384x640 20 persons, 2 skiss, 3 skateboards, 3104.2ms
# 7: 384x640 20 persons, 2 skiss, 5 skateboards, 3104.2ms
# 8: 384x640 18 persons, 3 skiss, 3 skateboards, 3104.2ms
# 9: 384x640 21 persons, 5 skiss, 2 skateboards, 3104.2ms
# 10: 384x640 22 persons, 5 skiss, 2 skateboards, 3104.2ms
# 11: 384x640 22 persons, 7 skiss, 2 skateboards, 3104.2ms
# 12: 384x640 23 persons, 6 skiss, 1 snowboard, 1 skateboard, 3104.2ms
# 13: 384x640 23 persons, 5 skiss, 1 snowboard, 2 skateboards, 3104.2ms
# 14: 384x640 23 persons, 1 skis, 2 skateboards, 3104.2ms
# 15: 384x640 23 persons, 3 skiss, 1 skateboard, 3104.2ms
# 16: 384x640 20 persons, 8 skiss, 1 skateboard, 3104.2ms
# 17: 384x640 18 persons, 6 skiss, 3104.2ms
# 18: 384x640 22 persons, 6 skiss, 1 skateboard, 3104.2ms
# 19: 384x640 21 persons, 6 skiss, 3104.2ms
# Speed: 6.1ms preprocess, 3104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 4 skiss, 1 skateboard, 3124.4ms
# 1: 384x640 21 persons, 4 skiss, 2 skateboards, 3124.4ms
# 2: 384x640 20 persons, 4 skiss, 1 skateboard, 3124.4ms
# 3: 384x640 21 persons, 4 skiss, 1 skateboard, 3124.4ms
# 4: 384x640 20 persons, 7 skiss, 1 skateboard, 3124.4ms
# 5: 384x640 22 persons, 7 skiss, 1 skateboard, 3124.4ms
# 6: 384x640 20 persons, 6 skiss, 2 skateboards, 3124.4ms
# 7: 384x640 18 persons, 6 skiss, 2 skateboards, 3124.4ms
# 8: 384x640 20 persons, 6 skiss, 1 skateboard, 3124.4ms
# 9: 384x640 18 persons, 6 skiss, 1 skateboard, 3124.4ms
# 10: 384x640 18 persons, 5 skiss, 1 skateboard, 3124.4ms
# 11: 384x640 20 persons, 5 skiss, 3124.4ms
# 12: 384x640 21 persons, 6 skiss, 1 skateboard, 3124.4ms
# 13: 384x640 22 persons, 5 skiss, 1 baseball bat, 1 skateboard, 3124.4ms
# 14: 384x640 19 persons, 5 skiss, 3124.4ms
# 15: 384x640 21 persons, 3 skiss, 3124.4ms
# 16: 384x640 21 persons, 7 skiss, 1 snowboard, 3124.4ms
# 17: 384x640 21 persons, 8 skiss, 1 snowboard, 3124.4ms
# 18: 384x640 23 persons, 8 skiss, 1 snowboard, 3124.4ms
# 19: 384x640 23 persons, 7 skiss, 3124.4ms
# Speed: 6.3ms preprocess, 3124.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 4 skiss, 1 snowboard, 3074.4ms
# 1: 384x640 23 persons, 6 skiss, 1 snowboard, 3074.4ms
# 2: 384x640 22 persons, 8 skiss, 3074.4ms
# 3: 384x640 22 persons, 7 skiss, 3074.4ms
# 4: 384x640 22 persons, 7 skiss, 3074.4ms
# 5: 384x640 25 persons, 10 skiss, 3074.4ms
# 6: 384x640 24 persons, 7 skiss, 3074.4ms
# 7: 384x640 22 persons, 8 skiss, 1 skateboard, 3074.4ms
# 8: 384x640 21 persons, 6 skiss, 1 skateboard, 3074.4ms
# 9: 384x640 21 persons, 5 skiss, 1 skateboard, 3074.4ms
# 10: 384x640 24 persons, 6 skiss, 1 skateboard, 3074.4ms
# 11: 384x640 25 persons, 6 skiss, 3074.4ms
# 12: 384x640 22 persons, 8 skiss, 3074.4ms
# 13: 384x640 23 persons, 7 skiss, 3074.4ms
# 14: 384x640 22 persons, 5 skiss, 3074.4ms
# 15: 384x640 22 persons, 4 skiss, 3074.4ms
# 16: 384x640 21 persons, 5 skiss, 3074.4ms
# 17: 384x640 21 persons, 6 skiss, 3074.4ms
# 18: 384x640 21 persons, 4 skiss, 3074.4ms
# 19: 384x640 21 persons, 6 skiss, 3074.4ms
# Speed: 5.3ms preprocess, 3074.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 6 skiss, 3114.7ms
# 1: 384x640 22 persons, 11 skiss, 3114.7ms
# 2: 384x640 24 persons, 6 skiss, 3114.7ms
# 3: 384x640 25 persons, 5 skiss, 3114.7ms
# 4: 384x640 24 persons, 4 skiss, 3114.7ms
# 5: 384x640 23 persons, 5 skiss, 3114.7ms
# 6: 384x640 21 persons, 3 skiss, 3114.7ms
# 7: 384x640 23 persons, 2 skiss, 3114.7ms
# 8: 384x640 23 persons, 5 skiss, 3114.7ms
# 9: 384x640 25 persons, 5 skiss, 1 snowboard, 3114.7ms
# 10: 384x640 25 persons, 5 skiss, 1 snowboard, 3114.7ms
# 11: 384x640 26 persons, 6 skiss, 1 snowboard, 3114.7ms
# 12: 384x640 25 persons, 6 skiss, 3114.7ms
# 13: 384x640 26 persons, 5 skiss, 1 snowboard, 3114.7ms
# 14: 384x640 25 persons, 5 skiss, 1 snowboard, 3114.7ms
# 15: 384x640 26 persons, 7 skiss, 3114.7ms
# 16: 384x640 26 persons, 4 skiss, 3114.7ms
# 17: 384x640 25 persons, 5 skiss, 3114.7ms
# 18: 384x640 23 persons, 2 skiss, 3114.7ms
# 19: 384x640 28 persons, 4 skiss, 3114.7ms
# Speed: 4.4ms preprocess, 3114.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 3 skiss, 3025.6ms
# 1: 384x640 24 persons, 3 skiss, 3025.6ms
# 2: 384x640 21 persons, 3 skiss, 3025.6ms
# 3: 384x640 23 persons, 3 skiss, 3025.6ms
# 4: 384x640 24 persons, 4 skiss, 3025.6ms
# 5: 384x640 24 persons, 6 skiss, 3025.6ms
# 6: 384x640 24 persons, 5 skiss, 3025.6ms
# 7: 384x640 23 persons, 5 skiss, 3025.6ms
# 8: 384x640 23 persons, 4 skiss, 3025.6ms
# 9: 384x640 24 persons, 5 skiss, 3025.6ms
# 10: 384x640 26 persons, 1 skis, 3025.6ms
# 11: 384x640 25 persons, 3 skiss, 3025.6ms
# 12: 384x640 26 persons, 1 skis, 3025.6ms
# 13: 384x640 26 persons, 3025.6ms
# 14: 384x640 25 persons, 1 backpack, 3025.6ms
# 15: 384x640 24 persons, 3025.6ms
# 16: 384x640 25 persons, 1 skis, 3025.6ms
# 17: 384x640 23 persons, 2 skiss, 3025.6ms
# 18: 384x640 24 persons, 3 skiss, 3025.6ms
# 19: 384x640 24 persons, 2 skiss, 3025.6ms
# Speed: 10.6ms preprocess, 3025.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 skiss, 3142.1ms
# 1: 384x640 25 persons, 4 skiss, 3142.1ms
# 2: 384x640 26 persons, 4 skiss, 3142.1ms
# 3: 384x640 27 persons, 6 skiss, 3142.1ms
# 4: 384x640 28 persons, 6 skiss, 3142.1ms
# 5: 384x640 27 persons, 2 skiss, 3142.1ms
# 6: 384x640 28 persons, 3 skiss, 3142.1ms
# 7: 384x640 30 persons, 2 skiss, 3142.1ms
# 8: 384x640 28 persons, 3 skiss, 3142.1ms
# 9: 384x640 28 persons, 3142.1ms
# 10: 384x640 28 persons, 2 skiss, 3142.1ms
# 11: 384x640 26 persons, 4 skiss, 3142.1ms
# 12: 384x640 27 persons, 2 skiss, 3142.1ms
# 13: 384x640 23 persons, 2 skiss, 3142.1ms
# 14: 384x640 24 persons, 4 skiss, 3142.1ms
# 15: 384x640 24 persons, 5 skiss, 3142.1ms
# 16: 384x640 26 persons, 4 skiss, 3142.1ms
# 17: 384x640 26 persons, 6 skiss, 3142.1ms
# 18: 384x640 24 persons, 2 skiss, 3142.1ms
# 19: 384x640 23 persons, 4 skiss, 3142.1ms
# Speed: 5.0ms preprocess, 3142.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 3 skiss, 3168.8ms
# 1: 384x640 25 persons, 2 skiss, 3168.8ms
# 2: 384x640 24 persons, 2 skiss, 3168.8ms
# 3: 384x640 24 persons, 3 skiss, 3168.8ms
# 4: 384x640 21 persons, 3 skiss, 3168.8ms
# 5: 384x640 23 persons, 2 skiss, 3168.8ms
# 6: 384x640 24 persons, 2 skiss, 3168.8ms
# 7: 384x640 27 persons, 2 skiss, 3168.8ms
# 8: 384x640 22 persons, 3 skiss, 3168.8ms
# 9: 384x640 23 persons, 5 skiss, 3168.8ms
# 10: 384x640 24 persons, 5 skiss, 3168.8ms
# 11: 384x640 21 persons, 7 skiss, 3168.8ms
# 12: 384x640 21 persons, 6 skiss, 3168.8ms
# 13: 384x640 20 persons, 7 skiss, 3168.8ms
# 14: 384x640 21 persons, 6 skiss, 3168.8ms
# 15: 384x640 21 persons, 6 skiss, 3168.8ms
# 16: 384x640 20 persons, 6 skiss, 3168.8ms
# 17: 384x640 21 persons, 5 skiss, 3168.8ms
# 18: 384x640 21 persons, 4 skiss, 3168.8ms
# 19: 384x640 22 persons, 4 skiss, 3168.8ms
# Speed: 5.4ms preprocess, 3168.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 skiss, 3114.5ms
# 1: 384x640 22 persons, 2 skiss, 3114.5ms
# 2: 384x640 24 persons, 1 skis, 3114.5ms
# 3: 384x640 21 persons, 2 skiss, 3114.5ms
# 4: 384x640 20 persons, 3114.5ms
# 5: 384x640 20 persons, 3114.5ms
# 6: 384x640 20 persons, 2 skiss, 3114.5ms
# 7: 384x640 19 persons, 2 skiss, 3114.5ms
# 8: 384x640 21 persons, 2 skiss, 3114.5ms
# 9: 384x640 18 persons, 1 skis, 3114.5ms
# 10: 384x640 22 persons, 2 skiss, 3114.5ms
# 11: 384x640 19 persons, 3 skiss, 1 baseball bat, 3114.5ms
# 12: 384x640 20 persons, 2 skiss, 3114.5ms
# 13: 384x640 17 persons, 2 skiss, 3114.5ms
# 14: 384x640 16 persons, 2 skiss, 3114.5ms
# 15: 384x640 19 persons, 2 skiss, 3114.5ms
# 16: 384x640 18 persons, 2 skiss, 3114.5ms
# 17: 384x640 23 persons, 2 skiss, 3114.5ms
# 18: 384x640 21 persons, 2 skiss, 3114.5ms
# 19: 384x640 21 persons, 4 skiss, 3114.5ms
# Speed: 4.4ms preprocess, 3114.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 8 skiss, 3107.5ms
# 1: 384x640 23 persons, 7 skiss, 3107.5ms
# 2: 384x640 23 persons, 6 skiss, 3107.5ms
# 3: 384x640 21 persons, 6 skiss, 1 skateboard, 3107.5ms
# 4: 384x640 25 persons, 6 skiss, 3107.5ms
# 5: 384x640 24 persons, 6 skiss, 3107.5ms
# 6: 384x640 22 persons, 4 skiss, 3107.5ms
# 7: 384x640 20 persons, 5 skiss, 3107.5ms
# 8: 384x640 23 persons, 8 skiss, 3107.5ms
# 9: 384x640 25 persons, 8 skiss, 3107.5ms
# 10: 384x640 23 persons, 4 skiss, 3107.5ms
# 11: 384x640 26 persons, 4 skiss, 3107.5ms
# 12: 384x640 25 persons, 5 skiss, 3107.5ms
# 13: 384x640 25 persons, 2 skiss, 3107.5ms
# 14: 384x640 25 persons, 2 skiss, 3107.5ms
# 15: 384x640 22 persons, 2 skiss, 3107.5ms
# 16: 384x640 23 persons, 5 skiss, 3107.5ms
# 17: 384x640 21 persons, 7 skiss, 3107.5ms
# 18: 384x640 21 persons, 6 skiss, 3107.5ms
# 19: 384x640 23 persons, 7 skiss, 3107.5ms
# Speed: 10.5ms preprocess, 3107.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 9 skiss, 3125.9ms
# 1: 384x640 20 persons, 8 skiss, 3125.9ms
# 2: 384x640 19 persons, 7 skiss, 3125.9ms
# 3: 384x640 18 persons, 10 skiss, 3125.9ms
# 4: 384x640 19 persons, 7 skiss, 3125.9ms
# 5: 384x640 18 persons, 6 skiss, 3125.9ms
# 6: 384x640 18 persons, 5 skiss, 1 snowboard, 3125.9ms
# 7: 384x640 21 persons, 5 skiss, 1 skateboard, 3125.9ms
# 8: 384x640 20 persons, 7 skiss, 1 skateboard, 3125.9ms
# 9: 384x640 20 persons, 8 skiss, 3125.9ms
# 10: 384x640 18 persons, 9 skiss, 1 skateboard, 3125.9ms
# 11: 384x640 18 persons, 9 skiss, 1 skateboard, 3125.9ms
# 12: 384x640 18 persons, 9 skiss, 3125.9ms
# 13: 384x640 16 persons, 12 skiss, 3125.9ms
# 14: 384x640 16 persons, 1 bench, 9 skiss, 3125.9ms
# 15: 384x640 16 persons, 8 skiss, 3125.9ms
# 16: 384x640 16 persons, 7 skiss, 3125.9ms
# 17: 384x640 17 persons, 8 skiss, 3125.9ms
# 18: 384x640 18 persons, 10 skiss, 3125.9ms
# 19: 384x640 19 persons, 9 skiss, 3125.9ms
# Speed: 4.3ms preprocess, 3125.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 8 skiss, 3181.0ms
# 1: 384x640 17 persons, 7 skiss, 3181.0ms
# 2: 384x640 18 persons, 1 backpack, 9 skiss, 3181.0ms
# 3: 384x640 19 persons, 13 skiss, 3181.0ms
# 4: 384x640 19 persons, 8 skiss, 3181.0ms
# 5: 384x640 18 persons, 5 skiss, 3181.0ms
# 6: 384x640 16 persons, 9 skiss, 3181.0ms
# 7: 384x640 19 persons, 10 skiss, 3181.0ms
# 8: 384x640 17 persons, 9 skiss, 3181.0ms
# 9: 384x640 18 persons, 9 skiss, 3181.0ms
# 10: 384x640 19 persons, 11 skiss, 1 skateboard, 3181.0ms
# 11: 384x640 17 persons, 11 skiss, 3181.0ms
# 12: 384x640 16 persons, 8 skiss, 3181.0ms
# 13: 384x640 17 persons, 9 skiss, 3181.0ms
# 14: 384x640 17 persons, 9 skiss, 3181.0ms
# 15: 384x640 17 persons, 7 skiss, 3181.0ms
# 16: 384x640 16 persons, 5 skiss, 3181.0ms
# 17: 384x640 17 persons, 5 skiss, 3181.0ms
# 18: 384x640 19 persons, 5 skiss, 3181.0ms
# 19: 384x640 17 persons, 6 skiss, 3181.0ms
# Speed: 5.5ms preprocess, 3181.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 6 skiss, 3105.4ms
# 1: 384x640 20 persons, 7 skiss, 3105.4ms
# 2: 384x640 19 persons, 6 skiss, 3105.4ms
# 3: 384x640 19 persons, 3 skiss, 3105.4ms
# 4: 384x640 19 persons, 3 skiss, 3105.4ms
# 5: 384x640 19 persons, 5 skiss, 3105.4ms
# 6: 384x640 19 persons, 10 skiss, 3105.4ms
# 7: 384x640 21 persons, 1 backpack, 10 skiss, 3105.4ms
# 8: 384x640 18 persons, 1 backpack, 8 skiss, 3105.4ms
# 9: 384x640 22 persons, 8 skiss, 3105.4ms
# 10: 384x640 20 persons, 9 skiss, 1 skateboard, 3105.4ms
# 11: 384x640 24 persons, 3 skiss, 3 skateboards, 3105.4ms
# 12: 384x640 26 persons, 5 skiss, 1 skateboard, 3105.4ms
# 13: 384x640 22 persons, 2 skiss, 2 skateboards, 3105.4ms
# 14: 384x640 22 persons, 10 skiss, 2 skateboards, 3105.4ms
# 15: 384x640 19 persons, 5 skiss, 2 skateboards, 3105.4ms
# 16: 384x640 20 persons, 5 skiss, 3105.4ms
# 17: 384x640 21 persons, 6 skiss, 3105.4ms
# 18: 384x640 21 persons, 5 skiss, 3105.4ms
# 19: 384x640 23 persons, 4 skiss, 3105.4ms
# Speed: 4.7ms preprocess, 3105.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 4 skiss, 3119.2ms
# 1: 384x640 24 persons, 3 skiss, 3119.2ms
# 2: 384x640 26 persons, 2 skiss, 3119.2ms
# 3: 384x640 29 persons, 3 skiss, 3119.2ms
# 4: 384x640 24 persons, 1 bench, 3 skiss, 3119.2ms
# 5: 384x640 23 persons, 1 skis, 3119.2ms
# 6: 384x640 23 persons, 2 skiss, 3119.2ms
# 7: 384x640 21 persons, 1 backpack, 2 skiss, 3119.2ms
# 8: 384x640 20 persons, 3 skiss, 1 skateboard, 3119.2ms
# 9: 384x640 19 persons, 4 skiss, 3119.2ms
# 10: 384x640 21 persons, 1 backpack, 4 skiss, 3119.2ms
# 11: 384x640 19 persons, 3 skiss, 1 snowboard, 1 skateboard, 3119.2ms
# 12: 384x640 22 persons, 3 skiss, 1 snowboard, 2 skateboards, 3119.2ms
# 13: 384x640 23 persons, 2 backpacks, 2 skiss, 1 baseball bat, 1 skateboard, 3119.2ms
# 14: 384x640 21 persons, 2 backpacks, 3 skiss, 1 skateboard, 3119.2ms
# 15: 384x640 20 persons, 1 backpack, 5 skiss, 1 skateboard, 3119.2ms
# 16: 384x640 19 persons, 1 backpack, 3 skiss, 1 skateboard, 3119.2ms
# 17: 384x640 21 persons, 1 backpack, 2 skiss, 1 skateboard, 3119.2ms
# 18: 384x640 23 persons, 2 backpacks, 1 skis, 1 skateboard, 3119.2ms
# 19: 384x640 20 persons, 1 car, 3 backpacks, 2 skateboards, 3119.2ms
# Speed: 4.7ms preprocess, 3119.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 1 skis, 1 skateboard, 3086.8ms
# 1: 384x640 22 persons, 1 backpack, 1 skis, 1 snowboard, 1 skateboard, 3086.8ms
# 2: 384x640 19 persons, 1 skis, 1 snowboard, 1 skateboard, 3086.8ms
# 3: 384x640 21 persons, 2 skiss, 1 skateboard, 3086.8ms
# 4: 384x640 23 persons, 1 backpack, 2 skateboards, 3086.8ms
# 5: 384x640 24 persons, 1 backpack, 1 snowboard, 2 skateboards, 3086.8ms
# 6: 384x640 21 persons, 1 snowboard, 2 skateboards, 3086.8ms
# 7: 384x640 26 persons, 2 skateboards, 3086.8ms
# 8: 384x640 23 persons, 2 skateboards, 3086.8ms
# 9: 384x640 20 persons, 2 skiss, 2 skateboards, 3086.8ms
# 10: 384x640 23 persons, 2 skiss, 1 skateboard, 3086.8ms
# 11: 384x640 21 persons, 1 skis, 2 skateboards, 3086.8ms
# 12: 384x640 19 persons, 1 skis, 1 skateboard, 3086.8ms
# 13: 384x640 19 persons, 1 skis, 1 snowboard, 1 skateboard, 3086.8ms
# 14: 384x640 21 persons, 1 skateboard, 3086.8ms
# 15: 384x640 22 persons, 1 skateboard, 3086.8ms
# 16: 384x640 21 persons, 3 skateboards, 3086.8ms
# 17: 384x640 23 persons, 3 skateboards, 3086.8ms
# 18: 384x640 22 persons, 1 skis, 3 skateboards, 3086.8ms
# 19: 384x640 23 persons, 3 skiss, 3 skateboards, 3086.8ms
# Speed: 6.4ms preprocess, 3086.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 2 skiss, 1 skateboard, 3109.5ms
# 1: 384x640 22 persons, 1 skis, 1 snowboard, 3 skateboards, 3109.5ms
# 2: 384x640 23 persons, 2 skateboards, 3109.5ms
# 3: 384x640 21 persons, 1 skis, 1 snowboard, 2 skateboards, 3109.5ms
# 4: 384x640 21 persons, 1 skis, 1 skateboard, 3109.5ms
# 5: 384x640 22 persons, 2 skateboards, 3109.5ms
# 6: 384x640 22 persons, 1 skateboard, 3109.5ms
# 7: 384x640 20 persons, 1 skis, 1 snowboard, 2 skateboards, 3109.5ms
# 8: 384x640 18 persons, 2 skiss, 2 skateboards, 3109.5ms
# 9: 384x640 19 persons, 2 skiss, 1 skateboard, 3109.5ms
# 10: 384x640 19 persons, 1 skis, 1 skateboard, 3109.5ms
# 11: 384x640 22 persons, 1 skateboard, 3109.5ms
# 12: 384x640 22 persons, 1 skateboard, 3109.5ms
# 13: 384x640 25 persons, 2 skateboards, 3109.5ms
# 14: 384x640 25 persons, 1 skis, 3 skateboards, 3109.5ms
# 15: 384x640 25 persons, 3 skateboards, 3109.5ms
# 16: 384x640 26 persons, 1 handbag, 1 skis, 3 skateboards, 3109.5ms
# 17: 384x640 20 persons, 2 skiss, 2 skateboards, 3109.5ms
# 18: 384x640 21 persons, 1 bench, 1 skis, 2 skateboards, 3109.5ms
# 19: 384x640 23 persons, 2 skateboards, 3109.5ms
# Speed: 4.7ms preprocess, 3109.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 skiss, 2 skateboards, 3087.8ms
# 1: 384x640 23 persons, 3 skiss, 1 skateboard, 3087.8ms
# 2: 384x640 23 persons, 1 skis, 1 skateboard, 3087.8ms
# 3: 384x640 22 persons, 1 skis, 2 skateboards, 3087.8ms
# 4: 384x640 22 persons, 2 skiss, 3 skateboards, 3087.8ms
# 5: 384x640 21 persons, 2 skiss, 1 skateboard, 3087.8ms
# 6: 384x640 19 persons, 4 skateboards, 3087.8ms
# 7: 384x640 18 persons, 3 skateboards, 3087.8ms
# 8: 384x640 18 persons, 1 car, 1 snowboard, 4 skateboards, 3087.8ms
# 9: 384x640 21 persons, 1 car, 1 skis, 2 snowboards, 3 skateboards, 3087.8ms
# 10: 384x640 21 persons, 1 car, 1 skis, 1 snowboard, 2 skateboards, 3087.8ms
# 11: 384x640 23 persons, 1 car, 1 skis, 1 snowboard, 3 skateboards, 3087.8ms
# 12: 384x640 21 persons, 1 car, 1 skis, 1 skateboard, 3087.8ms
# 13: 384x640 20 persons, 1 skis, 1 snowboard, 2 skateboards, 3087.8ms
# 14: 384x640 19 persons, 1 handbag, 1 baseball bat, 1 skateboard, 3087.8ms
# 15: 384x640 19 persons, 1 handbag, 1 baseball glove, 3 skateboards, 3087.8ms
# 16: 384x640 19 persons, 1 handbag, 1 skis, 1 baseball bat, 2 skateboards, 3087.8ms
# 17: 384x640 17 persons, 1 skis, 1 baseball glove, 2 skateboards, 3087.8ms
# 18: 384x640 21 persons, 1 skis, 1 snowboard, 1 baseball bat, 1 baseball glove, 1 skateboard, 2 tennis rackets, 3087.8ms
# 19: 384x640 21 persons, 2 skiss, 1 snowboard, 1 baseball bat, 1 baseball glove, 1 skateboard, 1 tennis racket, 3087.8ms
# Speed: 5.3ms preprocess, 3087.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 4 skiss, 1 baseball bat, 3095.9ms
# 1: 384x640 23 persons, 3 skiss, 1 baseball bat, 3095.9ms
# 2: 384x640 21 persons, 3 skiss, 3095.9ms
# 3: 384x640 22 persons, 3 skiss, 1 skateboard, 3095.9ms
# 4: 384x640 24 persons, 1 car, 1 skis, 1 snowboard, 1 skateboard, 3095.9ms
# 5: 384x640 23 persons, 1 skis, 2 skateboards, 3095.9ms
# 6: 384x640 23 persons, 2 skiss, 1 skateboard, 3095.9ms
# 7: 384x640 23 persons, 3 skiss, 1 skateboard, 3095.9ms
# 8: 384x640 25 persons, 5 skiss, 3095.9ms
# 9: 384x640 26 persons, 5 skiss, 3095.9ms
# 10: 384x640 24 persons, 3 skiss, 1 snowboard, 3095.9ms
# 11: 384x640 24 persons, 4 skiss, 3095.9ms
# 12: 384x640 25 persons, 5 skiss, 3095.9ms
# 13: 384x640 21 persons, 7 skiss, 3095.9ms
# 14: 384x640 23 persons, 5 skiss, 1 snowboard, 3095.9ms
# 15: 384x640 25 persons, 5 skiss, 1 snowboard, 3095.9ms
# 16: 384x640 23 persons, 5 skiss, 1 snowboard, 3095.9ms
# 17: 384x640 24 persons, 5 skiss, 1 snowboard, 3095.9ms
# 18: 384x640 23 persons, 5 skiss, 1 sports ball, 1 chair, 3095.9ms
# 19: 384x640 24 persons, 3 skiss, 1 snowboard, 1 sports ball, 3095.9ms
# Speed: 5.7ms preprocess, 3095.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 7 skiss, 3158.1ms
# 1: 384x640 22 persons, 5 skiss, 3158.1ms
# 2: 384x640 22 persons, 6 skiss, 1 snowboard, 3158.1ms
# 3: 384x640 23 persons, 5 skiss, 1 snowboard, 3158.1ms
# 4: 384x640 21 persons, 7 skiss, 1 snowboard, 3158.1ms
# 5: 384x640 19 persons, 8 skiss, 3158.1ms
# 6: 384x640 19 persons, 7 skiss, 1 snowboard, 3158.1ms
# 7: 384x640 20 persons, 8 skiss, 1 snowboard, 3158.1ms
# 8: 384x640 19 persons, 5 skiss, 1 baseball bat, 3158.1ms
# 9: 384x640 21 persons, 7 skiss, 1 snowboard, 1 baseball bat, 3158.1ms
# 10: 384x640 22 persons, 6 skiss, 1 snowboard, 3158.1ms
# 11: 384x640 22 persons, 7 skiss, 1 baseball bat, 3158.1ms
# 12: 384x640 23 persons, 7 skiss, 1 baseball bat, 3158.1ms
# 13: 384x640 22 persons, 8 skiss, 1 baseball bat, 3158.1ms
# 14: 384x640 21 persons, 9 skiss, 3158.1ms
# 15: 384x640 22 persons, 8 skiss, 3158.1ms
# 16: 384x640 24 persons, 5 skiss, 3158.1ms
# 17: 384x640 22 persons, 8 skiss, 3158.1ms
# 18: 384x640 22 persons, 1 bench, 7 skiss, 3158.1ms
# 19: 384x640 26 persons, 1 truck, 1 bench, 4 skiss, 1 snowboard, 2 skateboards, 3158.1ms
# Speed: 7.7ms preprocess, 3158.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bench, 3 skiss, 3135.1ms
# 1: 384x640 25 persons, 2 skiss, 2 tennis rackets, 3135.1ms
# 2: 384x640 25 persons, 1 bench, 3 skiss, 3 snowboards, 1 skateboard, 3135.1ms
# 3: 384x640 26 persons, 1 bench, 3 skiss, 2 snowboards, 1 skateboard, 3135.1ms
# 4: 384x640 27 persons, 1 bench, 3 skiss, 1 snowboard, 3135.1ms
# 5: 384x640 27 persons, 1 bench, 2 skiss, 1 snowboard, 1 skateboard, 3135.1ms
# 6: 384x640 26 persons, 1 skis, 1 snowboard, 1 skateboard, 3135.1ms
# 7: 384x640 21 persons, 1 car, 2 skiss, 1 snowboard, 3 skateboards, 3135.1ms
# 8: 384x640 19 persons, 1 car, 2 skiss, 1 snowboard, 3 skateboards, 3135.1ms
# 9: 384x640 21 persons, 5 skiss, 1 snowboard, 1 baseball bat, 1 skateboard, 3135.1ms
# 10: 384x640 24 persons, 5 skiss, 1 baseball bat, 2 skateboards, 3135.1ms
# 11: 384x640 24 persons, 1 car, 4 skiss, 1 baseball bat, 3 skateboards, 3135.1ms
# 12: 384x640 24 persons, 1 car, 3 skiss, 1 baseball bat, 2 skateboards, 3135.1ms
# 13: 384x640 23 persons, 1 car, 1 skis, 6 skateboards, 3135.1ms
# 14: 384x640 23 persons, 3 skiss, 2 snowboards, 3 skateboards, 3135.1ms
# 15: 384x640 22 persons, 1 car, 1 skis, 1 snowboard, 4 skateboards, 3135.1ms
# 16: 384x640 22 persons, 2 skiss, 1 snowboard, 5 skateboards, 3135.1ms
# 17: 384x640 22 persons, 3 skiss, 3 skateboards, 3135.1ms
# 18: 384x640 23 persons, 3 skiss, 3 skateboards, 3135.1ms
# 19: 384x640 25 persons, 3 skiss, 2 skateboards, 3135.1ms
# Speed: 5.4ms preprocess, 3135.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 6 skiss, 1 skateboard, 3107.2ms
# 1: 384x640 19 persons, 4 skiss, 1 snowboard, 3107.2ms
# 2: 384x640 19 persons, 5 skiss, 3107.2ms
# 3: 384x640 21 persons, 2 skiss, 1 skateboard, 3107.2ms
# 4: 384x640 20 persons, 2 skiss, 1 skateboard, 3107.2ms
# 5: 384x640 20 persons, 2 skiss, 1 skateboard, 3107.2ms
# 6: 384x640 19 persons, 4 skiss, 1 skateboard, 3107.2ms
# 7: 384x640 21 persons, 4 skiss, 3107.2ms
# 8: 384x640 24 persons, 4 skiss, 3107.2ms
# 9: 384x640 28 persons, 2 skiss, 2 snowboards, 1 baseball bat, 3107.2ms
# 10: 384x640 26 persons, 2 skiss, 2 snowboards, 1 baseball bat, 1 skateboard, 3107.2ms
# 11: 384x640 25 persons, 2 skiss, 4 snowboards, 1 baseball bat, 3107.2ms
# 12: 384x640 29 persons, 3 skiss, 4 snowboards, 1 baseball bat, 3107.2ms
# 13: 384x640 28 persons, 3 skiss, 4 snowboards, 2 skateboards, 3107.2ms
# 14: 384x640 27 persons, 3 skiss, 5 snowboards, 3107.2ms
# 15: 384x640 25 persons, 1 backpack, 5 skiss, 8 snowboards, 3107.2ms
# 16: 384x640 24 persons, 1 backpack, 3 skiss, 4 snowboards, 3 skateboards, 3107.2ms
# 17: 384x640 24 persons, 1 backpack, 5 skiss, 5 snowboards, 2 skateboards, 3107.2ms
# 18: 384x640 25 persons, 2 skiss, 2 snowboards, 2 skateboards, 3107.2ms
# 19: 384x640 28 persons, 4 skiss, 1 snowboard, 2 skateboards, 3107.2ms
# Speed: 5.1ms preprocess, 3107.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 5 skiss, 2 snowboards, 1 skateboard, 3097.3ms
# 1: 384x640 23 persons, 5 skiss, 2 snowboards, 2 skateboards, 3097.3ms
# 2: 384x640 23 persons, 2 skiss, 1 snowboard, 2 skateboards, 3097.3ms
# 3: 384x640 23 persons, 5 skiss, 1 snowboard, 2 skateboards, 3097.3ms
# 4: 384x640 21 persons, 5 skiss, 1 snowboard, 1 baseball bat, 1 skateboard, 3097.3ms
# 5: 384x640 22 persons, 1 backpack, 5 skiss, 2 snowboards, 1 baseball bat, 1 skateboard, 3097.3ms
# 6: 384x640 22 persons, 1 bench, 1 backpack, 2 skiss, 1 snowboard, 1 baseball bat, 1 skateboard, 3097.3ms
# 7: 384x640 23 persons, 1 bench, 1 backpack, 3 skiss, 1 snowboard, 1 skateboard, 3097.3ms
# 8: 384x640 26 persons, 1 car, 1 bench, 3 skiss, 1 snowboard, 3 skateboards, 3097.3ms
# 9: 384x640 23 persons, 1 car, 3 skiss, 3 skateboards, 3097.3ms
# 10: 384x640 21 persons, 1 truck, 1 bench, 4 skiss, 2 snowboards, 3 skateboards, 3097.3ms
# 11: 384x640 20 persons, 1 truck, 1 bench, 3 skiss, 2 snowboards, 2 skateboards, 3097.3ms
# 12: 384x640 21 persons, 1 bench, 3 skiss, 1 snowboard, 1 baseball bat, 2 skateboards, 3097.3ms
# 13: 384x640 20 persons, 3 skiss, 1 snowboard, 2 skateboards, 3097.3ms
# 14: 384x640 19 persons, 5 skiss, 1 snowboard, 2 skateboards, 3097.3ms
# 15: 384x640 19 persons, 5 skiss, 2 skateboards, 3097.3ms
# 16: 384x640 21 persons, 4 skiss, 1 snowboard, 2 skateboards, 3097.3ms
# 17: 384x640 21 persons, 5 skiss, 2 skateboards, 3097.3ms
# 18: 384x640 17 persons, 3 skiss, 2 snowboards, 1 skateboard, 3097.3ms
# 19: 384x640 23 persons, 4 skiss, 2 snowboards, 3097.3ms
# Speed: 4.5ms preprocess, 3097.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 skiss, 1 snowboard, 3105.8ms
# 1: 384x640 19 persons, 6 skiss, 3 snowboards, 3105.8ms
# 2: 384x640 20 persons, 5 skiss, 3 snowboards, 1 skateboard, 3105.8ms
# 3: 384x640 18 persons, 7 skiss, 1 skateboard, 3105.8ms
# 4: 384x640 17 persons, 3 skiss, 1 skateboard, 3105.8ms
# 5: 384x640 18 persons, 2 skiss, 1 skateboard, 3105.8ms
# 6: 384x640 16 persons, 1 dog, 2 skiss, 2 snowboards, 1 skateboard, 3105.8ms
# 7: 384x640 17 persons, 3 skiss, 2 snowboards, 3105.8ms
# 8: 384x640 17 persons, 2 skiss, 1 snowboard, 1 skateboard, 3105.8ms
# 9: 384x640 17 persons, 3 skiss, 2 snowboards, 3105.8ms
# 10: 384x640 17 persons, 3 skiss, 1 snowboard, 3105.8ms
# 11: 384x640 18 persons, 2 skiss, 1 skateboard, 3105.8ms
# 12: 384x640 20 persons, 1 skis, 1 skateboard, 3105.8ms
# 13: 384x640 19 persons, 4 skiss, 1 snowboard, 1 skateboard, 3105.8ms
# 14: 384x640 20 persons, 4 skiss, 3 snowboards, 3105.8ms
# 15: 384x640 22 persons, 5 skiss, 2 snowboards, 1 skateboard, 3105.8ms
# 16: 384x640 17 persons, 5 skiss, 3 skateboards, 3105.8ms
# 17: 384x640 20 persons, 6 skiss, 3 skateboards, 3105.8ms
# 18: 384x640 23 persons, 3 skiss, 1 snowboard, 1 skateboard, 3105.8ms
# 19: 384x640 24 persons, 4 skiss, 1 skateboard, 3105.8ms
# Speed: 5.1ms preprocess, 3105.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 skiss, 3 skateboards, 3165.5ms
# 1: 384x640 26 persons, 4 skiss, 4 skateboards, 3165.5ms
# 2: 384x640 26 persons, 3 skiss, 4 skateboards, 3165.5ms
# 3: 384x640 25 persons, 3 skiss, 1 snowboard, 2 skateboards, 3165.5ms
# 4: 384x640 25 persons, 2 skiss, 2 skateboards, 3165.5ms
# 5: 384x640 24 persons, 2 skiss, 1 snowboard, 1 skateboard, 3165.5ms
# 6: 384x640 25 persons, 1 skis, 1 snowboard, 1 baseball bat, 2 skateboards, 3165.5ms
# 7: 384x640 22 persons, 1 skis, 1 snowboard, 1 baseball bat, 1 skateboard, 3165.5ms
# 8: 384x640 22 persons, 1 backpack, 1 skis, 1 snowboard, 1 baseball bat, 1 skateboard, 3165.5ms
# 9: 384x640 21 persons, 1 skis, 1 baseball bat, 1 skateboard, 3165.5ms
# 10: 384x640 21 persons, 1 skis, 1 baseball bat, 2 skateboards, 3165.5ms
# 11: 384x640 19 persons, 1 skis, 1 skateboard, 3165.5ms
# 12: 384x640 20 persons, 1 skis, 3 skateboards, 3165.5ms
# 13: 384x640 22 persons, 1 skis, 2 skateboards, 3165.5ms
# 14: 384x640 20 persons, 2 skiss, 1 skateboard, 3165.5ms
# 15: 384x640 21 persons, 1 skis, 1 skateboard, 3165.5ms
# 16: 384x640 23 persons, 1 skis, 1 snowboard, 1 skateboard, 3165.5ms
# 17: 384x640 23 persons, 1 skis, 1 snowboard, 1 skateboard, 3165.5ms
# 18: 384x640 19 persons, 1 skis, 1 snowboard, 3165.5ms
# 19: 384x640 19 persons, 2 skiss, 1 snowboard, 1 skateboard, 3165.5ms
# Speed: 5.5ms preprocess, 3165.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 2 skiss, 3154.7ms
# 1: 384x640 21 persons, 1 skis, 1 snowboard, 3154.7ms
# 2: 384x640 22 persons, 2 skiss, 1 skateboard, 3154.7ms
# 3: 384x640 24 persons, 3 skiss, 3154.7ms
# 4: 384x640 21 persons, 4 skiss, 3154.7ms
# 5: 384x640 21 persons, 3 skiss, 3154.7ms
# 6: 384x640 20 persons, 4 skiss, 3154.7ms
# 7: 384x640 22 persons, 4 skiss, 3154.7ms
# 8: 384x640 23 persons, 4 skiss, 3154.7ms
# 9: 384x640 19 persons, 4 skiss, 1 skateboard, 3154.7ms
# 10: 384x640 19 persons, 4 skiss, 1 skateboard, 3154.7ms
# 11: 384x640 21 persons, 5 skiss, 3154.7ms
# 12: 384x640 18 persons, 5 skiss, 3154.7ms
# 13: 384x640 18 persons, 5 skiss, 3154.7ms
# 14: 384x640 18 persons, 4 skiss, 3154.7ms
# 15: 384x640 18 persons, 7 skiss, 3154.7ms
# 16: 384x640 18 persons, 6 skiss, 3154.7ms
# 17: 384x640 19 persons, 4 skiss, 3154.7ms
# 18: 384x640 18 persons, 4 skiss, 3154.7ms
# 19: 384x640 20 persons, 5 skiss, 3154.7ms
# Speed: 4.7ms preprocess, 3154.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 4 skiss, 3140.2ms
# 1: 384x640 23 persons, 4 skiss, 3140.2ms
# 2: 384x640 25 persons, 6 skiss, 3140.2ms
# 3: 384x640 27 persons, 5 skiss, 3140.2ms
# 4: 384x640 23 persons, 5 skiss, 3140.2ms
# 5: 384x640 25 persons, 3 skiss, 3140.2ms
# 6: 384x640 22 persons, 2 skiss, 1 snowboard, 1 skateboard, 3140.2ms
# 7: 384x640 18 persons, 1 skis, 1 snowboard, 1 skateboard, 3140.2ms
# 8: 384x640 17 persons, 1 skis, 1 snowboard, 1 skateboard, 3140.2ms
# 9: 384x640 19 persons, 1 skis, 1 snowboard, 1 skateboard, 3140.2ms
# 10: 384x640 19 persons, 1 skis, 1 snowboard, 1 skateboard, 3140.2ms
# 11: 384x640 18 persons, 1 skis, 1 snowboard, 1 skateboard, 3140.2ms
# 12: 384x640 19 persons, 2 skiss, 1 snowboard, 1 skateboard, 3140.2ms
# 13: 384x640 22 persons, 2 skiss, 1 skateboard, 3140.2ms
# 14: 384x640 20 persons, 3 skiss, 1 skateboard, 3140.2ms
# 15: 384x640 20 persons, 4 skiss, 1 snowboard, 1 skateboard, 3140.2ms
# 16: 384x640 21 persons, 3 skiss, 3140.2ms
# 17: 384x640 21 persons, 1 skis, 1 snowboard, 3140.2ms
# 18: 384x640 22 persons, 1 skis, 1 snowboard, 3140.2ms
# 19: 384x640 21 persons, 2 skiss, 3140.2ms
# Speed: 5.6ms preprocess, 3140.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 skis, 3098.0ms
# 1: 384x640 19 persons, 1 skis, 3098.0ms
# 2: 384x640 22 persons, 3 skiss, 1 skateboard, 3098.0ms
# 3: 384x640 19 persons, 2 skiss, 3098.0ms
# 4: 384x640 22 persons, 4 skiss, 3098.0ms
# 5: 384x640 21 persons, 3 skiss, 3098.0ms
# 6: 384x640 21 persons, 2 skiss, 3098.0ms
# 7: 384x640 18 persons, 2 skiss, 1 snowboard, 1 skateboard, 3098.0ms
# 8: 384x640 20 persons, 2 skiss, 1 skateboard, 3098.0ms
# 9: 384x640 20 persons, 2 skiss, 1 skateboard, 3098.0ms
# 10: 384x640 18 persons, 2 skiss, 1 skateboard, 3098.0ms
# 11: 384x640 18 persons, 3 skiss, 1 skateboard, 3098.0ms
# 12: 384x640 19 persons, 2 skiss, 1 skateboard, 3098.0ms
# 13: 384x640 20 persons, 2 skiss, 1 skateboard, 3098.0ms
# 14: 384x640 17 persons, 1 skis, 3098.0ms
# 15: 384x640 18 persons, 1 skis, 3098.0ms
# 16: 384x640 17 persons, 1 skis, 1 skateboard, 3098.0ms
# 17: 384x640 17 persons, 1 skis, 1 snowboard, 1 skateboard, 3098.0ms
# 18: 384x640 16 persons, 1 snowboard, 1 skateboard, 3098.0ms
# 19: 384x640 16 persons, 1 snowboard, 1 skateboard, 3098.0ms
# Speed: 5.6ms preprocess, 3098.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 snowboard, 3054.1ms
# 1: 384x640 18 persons, 1 snowboard, 3054.1ms
# 2: 384x640 16 persons, 1 snowboard, 3054.1ms
# 3: 384x640 17 persons, 1 snowboard, 3054.1ms
# 4: 384x640 14 persons, 3054.1ms
# 5: 384x640 14 persons, 3054.1ms
# 6: 384x640 15 persons, 1 snowboard, 3054.1ms
# 7: 384x640 14 persons, 1 skis, 1 snowboard, 3054.1ms
# 8: 384x640 15 persons, 1 snowboard, 3054.1ms
# 9: 384x640 16 persons, 1 skis, 3054.1ms
# 10: 384x640 16 persons, 3054.1ms
# 11: 384x640 18 persons, 1 skis, 3054.1ms
# 12: 384x640 20 persons, 3054.1ms
# 13: 384x640 18 persons, 1 skis, 3054.1ms
# 14: 384x640 21 persons, 3054.1ms
# 15: 384x640 20 persons, 3054.1ms
# 16: 384x640 20 persons, 1 snowboard, 3054.1ms
# 17: 384x640 21 persons, 1 snowboard, 3054.1ms
# 18: 384x640 23 persons, 1 skis, 3054.1ms
# 19: 384x640 25 persons, 2 skiss, 1 skateboard, 3054.1ms
# Speed: 5.1ms preprocess, 3054.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 3 skiss, 1 snowboard, 1 skateboard, 3181.0ms
# 1: 384x640 27 persons, 3 skiss, 3181.0ms
# 2: 384x640 27 persons, 3 skiss, 3181.0ms
# 3: 384x640 25 persons, 5 skiss, 1 skateboard, 3181.0ms
# 4: 384x640 23 persons, 4 skiss, 1 skateboard, 3181.0ms
# 5: 384x640 21 persons, 5 skiss, 3181.0ms
# 6: 384x640 24 persons, 5 skiss, 3181.0ms
# 7: 384x640 22 persons, 6 skiss, 3181.0ms
# 8: 384x640 24 persons, 3 skiss, 3181.0ms
# 9: 384x640 23 persons, 2 skiss, 3181.0ms
# 10: 384x640 25 persons, 3 skiss, 1 snowboard, 3181.0ms
# 11: 384x640 24 persons, 4 skiss, 1 snowboard, 3181.0ms
# 12: 384x640 23 persons, 2 skiss, 1 snowboard, 3181.0ms
# 13: 384x640 24 persons, 4 skiss, 1 snowboard, 1 skateboard, 3181.0ms
# 14: 384x640 24 persons, 7 skiss, 1 snowboard, 1 skateboard, 3181.0ms
# 15: 384x640 25 persons, 5 skiss, 1 snowboard, 1 skateboard, 3181.0ms
# 16: 384x640 23 persons, 7 skiss, 1 snowboard, 1 skateboard, 3181.0ms
# 17: 384x640 24 persons, 5 skiss, 1 snowboard, 1 skateboard, 3181.0ms
# 18: 384x640 23 persons, 5 skiss, 1 skateboard, 3181.0ms
# ...
# 8: 384x640 28 persons, 3 skiss, 3131.1ms
# 9: 384x640 27 persons, 3 skiss, 3131.1ms
# 10: 384x640 25 persons, 4 skiss, 3131.1ms
# 11: 384x640 26 persons, 2 skiss, 3131.1ms
# 12: 384x640 27 persons, 1 skis, 3131.1ms
# 13: 384x640 27 persons, 3 skiss, 3131.1ms
# 14: 384x640 26 persons, 2 skiss, 1 snowboard, 3131.1ms
# 15: 384x640 28 persons, 2 skiss, 3131.1ms
# 16: 384x640 26 persons, 3 skiss, 1 snowboard, 3131.1ms
# 17: 384x640 25 persons, 1 skis, 1 snowboard, 3131.1ms
# 18: 384x640 25 persons, 1 skis, 1 snowboard, 3131.1ms
# 19: 384x640 28 persons, 1 skis, 3131.1ms
# Speed: 4.2ms preprocess, 3131.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 2 skiss, 1 snowboard, 3158.4ms
# 1: 384x640 23 persons, 2 skiss, 3158.4ms
# 2: 384x640 27 persons, 2 skiss, 1 snowboard, 3158.4ms
# 3: 384x640 23 persons, 2 skiss, 3158.4ms
# 4: 384x640 25 persons, 2 skiss, 1 snowboard, 3158.4ms
# 5: 384x640 29 persons, 1 skis, 3158.4ms
# 6: 384x640 25 persons, 2 skiss, 3158.4ms
# 7: 384x640 22 persons, 2 skiss, 3158.4ms
# 8: 384x640 22 persons, 2 skiss, 3 snowboards, 3158.4ms
# 9: 384x640 18 persons, 2 skiss, 2 snowboards, 3158.4ms
# 10: 384x640 20 persons, 5 skiss, 2 snowboards, 1 baseball bat, 3158.4ms
# 11: 384x640 22 persons, 5 skiss, 2 snowboards, 3158.4ms
# 12: 384x640 21 persons, 4 skiss, 3158.4ms
# 13: 384x640 21 persons, 4 skiss, 3158.4ms
# 14: 384x640 19 persons, 1 backpack, 5 skiss, 3158.4ms
# 15: 384x640 21 persons, 1 backpack, 8 skiss, 3158.4ms
# 16: 384x640 21 persons, 1 backpack, 6 skiss, 3158.4ms
# 17: 384x640 20 persons, 6 skiss, 3158.4ms
# 18: 384x640 20 persons, 6 skiss, 3158.4ms
# 19: 384x640 21 persons, 5 skiss, 3158.4ms
# Speed: 5.8ms preprocess, 3158.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 4 skiss, 3092.2ms
# 1: 384x640 20 persons, 6 skiss, 3092.2ms
# 2: 384x640 21 persons, 6 skiss, 3092.2ms
# 3: 384x640 22 persons, 3 skiss, 3092.2ms
# 4: 384x640 19 persons, 5 skiss, 3092.2ms
# 5: 384x640 20 persons, 4 skiss, 3092.2ms
# 6: 384x640 20 persons, 4 skiss, 1 snowboard, 3092.2ms
# 7: 384x640 20 persons, 3 skiss, 1 snowboard, 3092.2ms
# 8: 384x640 20 persons, 1 snowboard, 3092.2ms
# 9: 384x640 18 persons, 1 skis, 1 snowboard, 3092.2ms
# 10: 384x640 15 persons, 2 skiss, 1 snowboard, 3092.2ms
# 11: 384x640 16 persons, 3 skiss, 1 skateboard, 3092.2ms
# 12: 384x640 15 persons, 2 skiss, 1 skateboard, 3092.2ms
# 13: 384x640 15 persons, 2 skiss, 3092.2ms
# 14: 384x640 14 persons, 1 skis, 3092.2ms
# 15: 384x640 14 persons, 3092.2ms
# 16: 384x640 16 persons, 1 skis, 3092.2ms
# 17: 384x640 17 persons, 1 skis, 2 snowboards, 3092.2ms
# 18: 384x640 18 persons, 2 snowboards, 1 skateboard, 3092.2ms
# 19: 384x640 20 persons, 1 backpack, 1 skis, 1 skateboard, 3092.2ms
# Speed: 7.2ms preprocess, 3092.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 backpacks, 1 skis, 1 skateboard, 3158.4ms
# 1: 384x640 19 persons, 4 backpacks, 1 skis, 1 skateboard, 3158.4ms
# 2: 384x640 20 persons, 3 backpacks, 1 skis, 2 skateboards, 3158.4ms
# 3: 384x640 20 persons, 2 backpacks, 2 skateboards, 3158.4ms
# 4: 384x640 18 persons, 1 backpack, 1 skis, 3158.4ms
# 5: 384x640 18 persons, 1 backpack, 3 skiss, 1 baseball bat, 3158.4ms
# 6: 384x640 18 persons, 1 backpack, 3 skiss, 3158.4ms
# 7: 384x640 19 persons, 5 skiss, 3158.4ms
# 8: 384x640 18 persons, 5 skiss, 3158.4ms
# 9: 384x640 21 persons, 4 skiss, 3158.4ms
# 10: 384x640 17 persons, 4 skiss, 3158.4ms
# 11: 384x640 18 persons, 5 skiss, 3158.4ms
# 12: 384x640 17 persons, 4 skiss, 3158.4ms
# 13: 384x640 20 persons, 4 skiss, 2 snowboards, 3158.4ms
# 14: 384x640 21 persons, 2 skiss, 1 snowboard, 3158.4ms
# 15: 384x640 19 persons, 2 skiss, 3158.4ms
# 16: 384x640 21 persons, 3 skiss, 3158.4ms
# 17: 384x640 15 persons, 1 skis, 3158.4ms
# 18: 384x640 22 persons, 4 skiss, 3158.4ms
# 19: 384x640 23 persons, 3 skiss, 3158.4ms
# Speed: 5.6ms preprocess, 3158.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 5 skiss, 3147.3ms
# 1: 384x640 21 persons, 5 skiss, 3147.3ms
# 2: 384x640 20 persons, 3 skiss, 3147.3ms
# 3: 384x640 23 persons, 5 skiss, 3147.3ms
# 4: 384x640 20 persons, 1 skis, 1 snowboard, 1 skateboard, 3147.3ms
# 5: 384x640 20 persons, 1 skateboard, 3147.3ms
# 6: 384x640 19 persons, 3 skiss, 1 skateboard, 3147.3ms
# 7: 384x640 22 persons, 7 skiss, 1 snowboard, 3147.3ms
# 8: 384x640 19 persons, 1 backpack, 7 skiss, 1 skateboard, 3147.3ms
# 9: 384x640 18 persons, 3 skiss, 1 skateboard, 3147.3ms
# 10: 384x640 20 persons, 3 skiss, 2 skateboards, 3147.3ms
# 11: 384x640 20 persons, 3 skiss, 2 snowboards, 1 skateboard, 3147.3ms
# 12: 384x640 21 persons, 3 skiss, 1 skateboard, 3147.3ms
# 13: 384x640 19 persons, 3 skiss, 1 snowboard, 1 skateboard, 3147.3ms
# 14: 384x640 19 persons, 2 skiss, 2 snowboards, 1 skateboard, 3147.3ms
# 15: 384x640 19 persons, 4 skiss, 1 snowboard, 1 skateboard, 3147.3ms
# 16: 384x640 19 persons, 3 skiss, 2 skateboards, 3147.3ms
# 17: 384x640 20 persons, 5 skiss, 1 skateboard, 3147.3ms
# 18: 384x640 20 persons, 5 skiss, 1 snowboard, 1 skateboard, 3147.3ms
# 19: 384x640 18 persons, 4 skiss, 1 skateboard, 3147.3ms
# Speed: 5.9ms preprocess, 3147.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 5 skiss, 2 skateboards, 3165.5ms
# 1: 384x640 16 persons, 5 skiss, 3 skateboards, 3165.5ms
# 2: 384x640 19 persons, 2 skiss, 4 skateboards, 3165.5ms
# 3: 384x640 18 persons, 3 skiss, 5 skateboards, 3165.5ms
# 4: 384x640 18 persons, 2 skiss, 1 snowboard, 3 skateboards, 3165.5ms
# 5: 384x640 19 persons, 1 skis, 2 snowboards, 3 skateboards, 3165.5ms
# 6: 384x640 20 persons, 6 skateboards, 3165.5ms
# 7: 384x640 19 persons, 1 skis, 1 snowboard, 3 skateboards, 3165.5ms
# 8: 384x640 19 persons, 1 skis, 3 snowboards, 4 skateboards, 3165.5ms
# 9: 384x640 20 persons, 1 skis, 1 snowboard, 3 skateboards, 3165.5ms
# 10: 384x640 18 persons, 1 skis, 1 snowboard, 5 skateboards, 3165.5ms
# 11: 384x640 17 persons, 1 skis, 1 snowboard, 5 skateboards, 3165.5ms
# 12: 384x640 17 persons, 1 skis, 1 snowboard, 2 skateboards, 3165.5ms
# 13: 384x640 17 persons, 4 skiss, 1 snowboard, 1 skateboard, 3165.5ms
# 14: 384x640 18 persons, 3 skiss, 2 snowboards, 3165.5ms
# 15: 384x640 16 persons, 3 skiss, 2 snowboards, 1 skateboard, 3165.5ms
# 16: 384x640 16 persons, 3 skiss, 1 skateboard, 3165.5ms
# 17: 384x640 16 persons, 2 skiss, 2 skateboards, 3165.5ms
# 18: 384x640 16 persons, 5 skiss, 3165.5ms
# 19: 384x640 18 persons, 7 skiss, 1 skateboard, 3165.5ms
# Speed: 6.8ms preprocess, 3165.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 7 skiss, 1 baseball bat, 1 skateboard, 3082.4ms
# 1: 384x640 17 persons, 7 skiss, 1 snowboard, 3082.4ms
# 2: 384x640 17 persons, 7 skiss, 3082.4ms
# 3: 384x640 20 persons, 7 skiss, 1 skateboard, 3082.4ms
# 4: 384x640 17 persons, 8 skiss, 1 skateboard, 3082.4ms
# 5: 384x640 20 persons, 7 skiss, 1 skateboard, 3082.4ms
# 6: 384x640 19 persons, 6 skiss, 3082.4ms
# 7: 384x640 19 persons, 4 skiss, 3082.4ms
# 8: 384x640 18 persons, 4 skiss, 1 baseball bat, 2 skateboards, 3082.4ms
# 9: 384x640 17 persons, 4 skiss, 2 baseball bats, 4 skateboards, 3082.4ms
# 10: 384x640 16 persons, 2 skiss, 1 baseball bat, 2 skateboards, 3082.4ms
# 11: 384x640 17 persons, 3 skiss, 1 baseball bat, 2 skateboards, 3082.4ms
# 12: 384x640 18 persons, 3 skiss, 2 baseball bats, 3 skateboards, 3082.4ms
# 13: 384x640 19 persons, 4 skiss, 1 skateboard, 3082.4ms
# 14: 384x640 19 persons, 7 skiss, 3 skateboards, 3082.4ms
# 15: 384x640 16 persons, 6 skiss, 2 skateboards, 3082.4ms
# 16: 384x640 14 persons, 4 skiss, 1 snowboard, 3082.4ms
# 17: 384x640 13 persons, 3 skiss, 3082.4ms
# 18: 384x640 13 persons, 1 backpack, 4 skiss, 1 skateboard, 3082.4ms
# 19: 384x640 14 persons, 1 backpack, 3 skiss, 1 snowboard, 2 skateboards, 3082.4ms
# Speed: 5.5ms preprocess, 3082.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 backpack, 4 skiss, 1 snowboard, 3137.7ms
# 1: 384x640 16 persons, 5 skiss, 1 snowboard, 3137.7ms
# 2: 384x640 15 persons, 4 skiss, 1 snowboard, 1 skateboard, 3137.7ms
# 3: 384x640 15 persons, 3 skiss, 1 snowboard, 3137.7ms
# 4: 384x640 16 persons, 2 skiss, 1 snowboard, 3137.7ms
# 5: 384x640 18 persons, 4 skiss, 1 snowboard, 3137.7ms
# 6: 384x640 18 persons, 5 skiss, 1 snowboard, 3137.7ms
# 7: 384x640 18 persons, 6 skiss, 1 snowboard, 3137.7ms
# 8: 384x640 19 persons, 5 skiss, 2 snowboards, 3137.7ms
# 9: 384x640 16 persons, 4 skiss, 2 snowboards, 3137.7ms
# 10: 384x640 18 persons, 3 skiss, 2 snowboards, 3137.7ms
# 11: 384x640 17 persons, 3 skiss, 1 snowboard, 3137.7ms
# 12: 384x640 15 persons, 2 skiss, 1 snowboard, 3137.7ms
# 13: 384x640 16 persons, 1 skis, 2 snowboards, 3137.7ms
# 14: 384x640 15 persons, 2 skiss, 1 snowboard, 3137.7ms
# 15: 384x640 16 persons, 2 skiss, 1 snowboard, 3137.7ms
# 16: 384x640 16 persons, 4 skiss, 1 snowboard, 3137.7ms
# 17: 384x640 16 persons, 3 skiss, 1 snowboard, 3137.7ms
# 18: 384x640 17 persons, 4 skiss, 1 snowboard, 3137.7ms
# 19: 384x640 16 persons, 3 skiss, 3137.7ms
# Speed: 6.3ms preprocess, 3137.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 3 skiss, 3062.0ms
# 1: 384x640 15 persons, 4 skiss, 3062.0ms
# 2: 384x640 16 persons, 3 skiss, 3062.0ms
# 3: 384x640 15 persons, 3 skiss, 3062.0ms
# 4: 384x640 15 persons, 2 skiss, 3062.0ms
# 5: 384x640 17 persons, 2 skiss, 1 snowboard, 3062.0ms
# 6: 384x640 16 persons, 2 skiss, 1 snowboard, 3062.0ms
# 7: 384x640 15 persons, 4 skiss, 2 snowboards, 3062.0ms
# 8: 384x640 15 persons, 2 skiss, 3 snowboards, 3062.0ms
# 9: 384x640 15 persons, 1 skis, 3 snowboards, 3062.0ms
# 10: 384x640 16 persons, 2 skiss, 2 snowboards, 3062.0ms
# 11: 384x640 15 persons, 4 skiss, 1 skateboard, 3062.0ms
# 12: 384x640 16 persons, 5 skiss, 1 snowboard, 1 skateboard, 3062.0ms
# 13: 384x640 15 persons, 4 skiss, 2 snowboards, 1 skateboard, 3062.0ms
# 14: 384x640 16 persons, 5 skiss, 1 skateboard, 3062.0ms
# 15: 384x640 19 persons, 5 skiss, 3 skateboards, 3062.0ms
# 16: 384x640 22 persons, 6 skiss, 3062.0ms
# 17: 384x640 21 persons, 4 skiss, 1 snowboard, 1 skateboard, 3062.0ms
# 18: 384x640 21 persons, 5 skiss, 1 skateboard, 3062.0ms
# 19: 384x640 21 persons, 6 skiss, 2 skateboards, 3062.0ms
# Speed: 7.1ms preprocess, 3062.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 5 skiss, 1 snowboard, 1 skateboard, 3030.2ms
# 1: 384x640 18 persons, 5 skiss, 1 skateboard, 3030.2ms
# 2: 384x640 20 persons, 6 skiss, 1 skateboard, 3030.2ms
# 3: 384x640 17 persons, 8 skiss, 1 snowboard, 2 skateboards, 3030.2ms
# 4: 384x640 15 persons, 5 skiss, 3030.2ms
# 5: 384x640 15 persons, 4 skiss, 3030.2ms
# 6: 384x640 15 persons, 4 skiss, 1 snowboard, 3030.2ms
# 7: 384x640 15 persons, 6 skiss, 1 snowboard, 3030.2ms
# 8: 384x640 14 persons, 7 skiss, 1 snowboard, 1 skateboard, 3030.2ms
# 9: 384x640 14 persons, 7 skiss, 1 skateboard, 3030.2ms
# 10: 384x640 16 persons, 7 skiss, 1 skateboard, 3030.2ms
# 11: 384x640 14 persons, 1 backpack, 6 skiss, 1 snowboard, 1 skateboard, 3030.2ms
# 12: 384x640 15 persons, 4 skiss, 2 skateboards, 3030.2ms
# 13: 384x640 15 persons, 6 skiss, 2 skateboards, 3030.2ms
# 14: 384x640 15 persons, 5 skiss, 2 skateboards, 3030.2ms
# 15: 384x640 15 persons, 3 skiss, 3 skateboards, 3030.2ms
# 16: 384x640 15 persons, 2 skiss, 1 snowboard, 1 skateboard, 3030.2ms
# 17: 384x640 14 persons, 2 skiss, 1 skateboard, 3030.2ms
# 18: 384x640 15 persons, 3 skiss, 1 skateboard, 3030.2ms
# 19: 384x640 15 persons, 6 skiss, 1 snowboard, 1 skateboard, 3030.2ms
# Speed: 6.9ms preprocess, 3030.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 5 skiss, 2 snowboards, 3100.3ms
# 1: 384x640 15 persons, 4 skiss, 2 snowboards, 1 skateboard, 3100.3ms
# 2: 384x640 15 persons, 7 skiss, 1 snowboard, 3100.3ms
# 3: 384x640 17 persons, 5 skiss, 1 skateboard, 3100.3ms
# 4: 384x640 18 persons, 4 skiss, 1 skateboard, 3100.3ms
# 5: 384x640 18 persons, 4 skiss, 1 skateboard, 3100.3ms
# 6: 384x640 15 persons, 3 skiss, 1 skateboard, 3100.3ms
# 7: 384x640 18 persons, 3 skiss, 1 skateboard, 3100.3ms
# 8: 384x640 15 persons, 3 skiss, 2 skateboards, 3100.3ms
# 9: 384x640 17 persons, 3 skiss, 2 skateboards, 3100.3ms
# 10: 384x640 19 persons, 2 skiss, 2 skateboards, 3100.3ms
# 11: 384x640 19 persons, 3 skiss, 1 skateboard, 3100.3ms
# 12: 384x640 19 persons, 3 skiss, 3100.3ms
# 13: 384x640 20 persons, 4 skiss, 3100.3ms
# 14: 384x640 17 persons, 5 skiss, 3100.3ms
# 15: 384x640 20 persons, 4 skiss, 1 skateboard, 3100.3ms
# 16: 384x640 20 persons, 5 skiss, 3100.3ms
# 17: 384x640 23 persons, 6 skiss, 1 skateboard, 3100.3ms
# 18: 384x640 20 persons, 6 skiss, 1 skateboard, 3100.3ms
# 19: 384x640 18 persons, 3 skiss, 3100.3ms
# Speed: 8.9ms preprocess, 3100.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 4 skiss, 3165.4ms
# 1: 384x640 21 persons, 3 skiss, 3165.4ms
# 2: 384x640 21 persons, 2 skiss, 3165.4ms
# 3: 384x640 20 persons, 3 skiss, 3165.4ms
# 4: 384x640 20 persons, 3 skiss, 3165.4ms
# 5: 384x640 21 persons, 4 skiss, 3165.4ms
# 6: 384x640 20 persons, 2 skiss, 3165.4ms
# 7: 384x640 19 persons, 2 skiss, 3165.4ms
# 8: 384x640 21 persons, 2 skiss, 1 skateboard, 3165.4ms
# 9: 384x640 21 persons, 3 skiss, 1 skateboard, 3165.4ms
# 10: 384x640 20 persons, 1 skis, 1 skateboard, 3165.4ms
# 11: 384x640 21 persons, 1 skis, 1 skateboard, 3165.4ms
# 12: 384x640 22 persons, 2 skiss, 3165.4ms
# 13: 384x640 21 persons, 3 skiss, 3165.4ms
# 14: 384x640 20 persons, 3 skiss, 3165.4ms
# 15: 384x640 21 persons, 2 skiss, 3165.4ms
# 16: 384x640 24 persons, 3 skiss, 3165.4ms
# 17: 384x640 23 persons, 2 skiss, 3165.4ms
# 18: 384x640 25 persons, 3 skiss, 3165.4ms
# 19: 384x640 25 persons, 1 skis, 3165.4ms
# Speed: 5.5ms preprocess, 3165.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 5 skiss, 3185.0ms
# 1: 384x640 20 persons, 4 skiss, 3185.0ms
# 2: 384x640 20 persons, 3 skiss, 3185.0ms
# 3: 384x640 20 persons, 2 skiss, 3185.0ms
# 4: 384x640 20 persons, 2 skiss, 3185.0ms
# 5: 384x640 22 persons, 4 skiss, 3185.0ms
# 6: 384x640 22 persons, 3 skiss, 3185.0ms
# 7: 384x640 22 persons, 1 skis, 3185.0ms
# 8: 384x640 26 persons, 2 skiss, 3185.0ms
# 9: 384x640 23 persons, 1 skis, 3185.0ms
# 10: 384x640 25 persons, 1 skis, 3185.0ms
# 11: 384x640 21 persons, 2 skiss, 3185.0ms
# 12: 384x640 25 persons, 2 skiss, 3185.0ms
# 13: 384x640 28 persons, 2 skiss, 3185.0ms
# 14: 384x640 23 persons, 1 skis, 3185.0ms
# 15: 384x640 22 persons, 1 skis, 3185.0ms
# 16: 384x640 24 persons, 1 skis, 3185.0ms
# 17: 384x640 28 persons, 3185.0ms
# 18: 384x640 29 persons, 3185.0ms
# 19: 384x640 27 persons, 3185.0ms
# Speed: 5.5ms preprocess, 3185.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 3126.3ms
# 1: 384x640 26 persons, 3126.3ms
# 2: 384x640 24 persons, 1 skis, 3126.3ms
# 3: 384x640 27 persons, 3126.3ms
# 4: 384x640 28 persons, 3126.3ms
# 5: 384x640 26 persons, 3126.3ms
# 6: 384x640 26 persons, 3126.3ms
# 7: 384x640 25 persons, 2 skiss, 3126.3ms
# 8: 384x640 23 persons, 3 skiss, 3126.3ms
# 9: 384x640 24 persons, 3 skiss, 3126.3ms
# 10: 384x640 26 persons, 3 skiss, 3126.3ms
# 11: 384x640 25 persons, 3 skiss, 3126.3ms
# 12: 384x640 24 persons, 3 skiss, 3126.3ms
# 13: 384x640 25 persons, 2 skiss, 3126.3ms
# 14: 384x640 28 persons, 2 skiss, 3126.3ms
# 15: 384x640 26 persons, 2 skiss, 3126.3ms
# 16: 384x640 31 persons, 2 skiss, 3126.3ms
# 17: 384x640 30 persons, 2 skiss, 3126.3ms
# 18: 384x640 30 persons, 1 skis, 3126.3ms
# 19: 384x640 26 persons, 3126.3ms
# Speed: 5.7ms preprocess, 3126.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 skis, 3074.1ms
# 1: 384x640 31 persons, 3074.1ms
# 2: 384x640 32 persons, 3074.1ms
# 3: 384x640 29 persons, 3074.1ms
# 4: 384x640 28 persons, 3074.1ms
# 5: 384x640 28 persons, 3074.1ms
# 6: 384x640 29 persons, 3074.1ms
# 7: 384x640 25 persons, 3074.1ms
# 8: 384x640 28 persons, 3074.1ms
# 9: 384x640 27 persons, 3074.1ms
# 10: 384x640 28 persons, 3074.1ms
# 11: 384x640 27 persons, 3074.1ms
# 12: 384x640 26 persons, 3074.1ms
# 13: 384x640 26 persons, 3074.1ms
# 14: 384x640 31 persons, 3074.1ms
# 15: 384x640 30 persons, 3074.1ms
# 16: 384x640 30 persons, 3074.1ms
# 17: 384x640 31 persons, 3074.1ms
# Speed: 5.6ms preprocess, 3074.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)

# %%
#************ Design of Ellipse for tracking players instead of Bounding boxes**************#

def draw_ellipse(self, frame, bbox, color, track_id=None, team=None):
  y2 = int(bbox[3])
  x_center = (int(bbox[0]) + int(bbox[2])) // 2
  width = int(bbox[2]) - int(bbox[0])
  color = (255, 0, 0)
  text_color = (255, 255, 255)

  cv2.ellipse(
      frame,
      center=(x_center, y2),
      axes=(int(width) // 2, int(0.35 * width)),
      angle=0.0,
      startAngle=-45,
      endAngle=235,
      color=color,
      thickness=2,
      lineType=cv2.LINE_4
  )

  if track_id is not None:
      rectangle_width = 40
      rectangle_height = 20
      x1_rect = x_center - rectangle_width // 2
      x2_rect = x_center + rectangle_width // 2
      y1_rect = (y2 - rectangle_height // 2) + 15
      y2_rect = (y2 + rectangle_height // 2) + 15

      cv2.rectangle(frame,
                    (int(x1_rect), int(y1_rect)),
                    (int(x2_rect), int(y2_rect)),
                    color,
                    cv2.FILLED)

      x1_text = x1_rect + 12
      if track_id > 99:
          x1_text -= 10
      font_scale = 0.4
      cv2.putText(
          frame,
          f"{track_id}",
          (int(x1_text), int(y1_rect + 15)),
          cv2.FONT_HERSHEY_SIMPLEX,
          font_scale,
          text_color,
          thickness=2
      )

  return frame

# %%
#***********************BOUNDING BOXES AND TRACK-IDs**************************#

def draw_annotations(self, video_frames, tracks):
  output_video_frames = []
  for frame_num, frame in enumerate(video_frames):
      frame = frame.copy()
      player_dict = tracks["person"][frame_num]

      # Draw Players
      for track_id, player in player_dict.items():
          bbox = player["bbox"]

      # Draw ellipse and tracking IDs
          self.draw_ellipse(frame, bbox, (0, 255, 0), track_id)

          x1, y1, x2, y2 = map(int, bbox)

      output_video_frames.append(frame)

  return output_video_frames

# %%
#********************* Border Definition for Frame***********************
import cv2

video_path = 'video_input.mp4'
cap = cv2.VideoCapture(video_path)

#**************Read, Define and Draw corners of the frame****************
ret, frame = cap.read()

bottom_left = (0, 720)
bottom_right = (1280, 720)
upper_left = (0, 0)
upper_right = (1280, 0)

cv2.line(frame, bottom_left, bottom_right, (0, 255, 0), 2)
cv2.line(frame, bottom_left, upper_left, (0, 255, 0), 2)
cv2.line(frame, bottom_right, upper_right, (0, 255, 0), 2)
cv2.line(frame, upper_left, upper_right, (0, 255, 0), 2)

#*******************Save the frame with marked corners*********************
output_image_path = 'rink_area_marked_VALIDATION.png'
cv2.imwrite(output_image_path, frame)
print("Rink area saved:", output_image_path)
# Out:
# Rink area saved: rink_area_marked_VALIDATION.png

# %% [markdown]
# **************YELLOW TEAM OFFENSIVE ZONE****************
#
# Bottom Left Corner: (-450, 710)
#
# Bottom Right Corner: (2030, 710)
#
# Upper Left Corner: (200, 150)
#
# Upper Right Corner: (1160, 150)
#
# **************WHITE TEAM OFFENSIVE ZONE****************
#
# Bottom Left Corner: (180, 150)
#
# Bottom Right Corner: (1100, 150)
#
# Upper Left Corner: (352, 61)
#
# Upper Right Corner: (900, 61)

# %%
# !pip install torch torchvision
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.18.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.82)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
# ************CONVOLUTIONAL NEURAL NETWORK-THREE CLASSES DETECTION**************************
# REFEREE
# WHITE TEAM (Team_away)
# YELLOW TEAM (Team_home)

import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

#Training and Validation Datasets
#Download the teams_sample_dataset file from the project's GitHub repository
data_dir = 'teams_sample_dataset'

# %%
#******************************Data transformation***********************************
transform = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load dataset
train_dataset = datasets.ImageFolder(os.path.join(data_dir, 'train'), transform=transform)
val_dataset = datasets.ImageFolder(os.path.join(data_dir, 'val'), transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-28c3b8b572b3> in <cell line: 9>()
#       7
#       8 # Load dataset
# ----> 9 train_dataset = datasets.ImageFolder(os.path.join(data_dir, 'train'), transform=transform)
#      10 val_dataset = datasets.ImageFolder(os.path.join(data_dir, 'val'), transform=transform)
#      11
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     326         allow_empty: bool = False,
#     327     ):
# --> 328         super().__init__(
#     329             root,
#     330             loader,
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     148         super().__init__(root, transform=transform, target_transform=target_transform)
#     149         classes, class_to_idx = self.find_classes(self.root)
# --> 150         samples = self.make_dataset(
#     151             self.root,
#     152             class_to_idx=class_to_idx,
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file, allow_empty)
#     201             # is potentially overridden and thus could have a different logic.
#     202             raise ValueError("The class_to_idx parameter cannot be None.")
# --> 203         return make_dataset(
#     204             directory, class_to_idx, extensions=extensions, is_valid_file=is_valid_file, allow_empty=allow_empty
#     205         )
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file, allow_empty)
#     102         if extensions is not None:
#     103             msg += f"Supported extensions are: {extensions if isinstance(extensions, str) else ', '.join(extensions)}"
# --> 104         raise FileNotFoundError(msg)
#     105
#     106     return instances
#
# FileNotFoundError: Found no valid file for the classes .ipynb_checkpoints. Supported extensions are: .jpg, .jpeg, .png, .ppm, .bmp, .pgm, .tif, .tiff, .webp

# %%
#********************************CNN Model Architecture**************************************
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(128 * 18 * 18, 512)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 3)  #Three Classes (Referee, Team_away,Team_home)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 18 * 18)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
#********************************CNN TRAINING**********************************************

# Model-loss function-optimizer
model = CNNModel()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

#*********************************Training*************************************************
num_epochs = 10
train_losses, val_losses = [], []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        labels = labels.type(torch.LongTensor)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    train_losses.append(running_loss / len(train_loader))

    model.eval()
    val_loss = 0.0
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            labels = labels.type(torch.LongTensor)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            all_labels.extend(labels.tolist())
            all_preds.extend(preds.tolist())

# %%
#********************************METRICS & PERFORMANCE************************************

    val_losses.append(val_loss / len(val_loader))
    val_accuracy = accuracy_score(all_labels, all_preds)
    val_precision = precision_score(all_labels, all_preds, average='macro', zero_division=1)
    val_recall = recall_score(all_labels, all_preds, average='macro', zero_division=1)
    val_f1 = f1_score(all_labels, all_preds, average='macro', zero_division=1)

    print(f"Epoch [{epoch + 1}/{num_epochs}], "
          f"Loss: {train_losses[-1]:.4f}, "
          f"Val Loss: {val_losses[-1]:.4f}, "
          f"Val Acc: {val_accuracy:.2%}, "
          f"Val Precision: {val_precision:.4f}, "
          f"Val Recall: {val_recall:.4f}, "
          f"Val F1 Score: {val_f1:.4f}")

#*******************************SHOW METRICS & PERFORMANCE**********************************
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.show()

# SAVE THE MODEL FOR THE GH_CV_track_teams CODE
torch.save(model.state_dict(), 'hockey_team_classifier.pth')

# %%
# *************TEST CNN MODEL WITH SAMPLE DATASET***************************

import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from PIL import Image

# SAMPLE DATASET FOR VALIDATION
test_dir = 'D:/PYTHON/validation_dataset'

# CNN MODEL FOR TEAM PREDICTIONS
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(128 * 18 * 18, 512)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 3)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 18 * 18)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# CNN MODEL PREVIOUSLY SAVED
model = CNNModel()
model.load_state_dict(torch.load('D:/PYTHON/hockey_team_classifier.pth'))
model.eval()

transform = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

#******************ITERATION ON SAMPLE IMAGES-ACCURACY TEST*****************************

class_names = ['team_referee', 'team_away', 'team_home']

def predict_image(image_path, model, transform):
# LOADS DATASET
    image = Image.open(image_path)
    image = transform(image).unsqueeze(0)

# MAKES PREDICTIONS
    with torch.no_grad():
        output = model(image)
        _, predicted = torch.max(output, 1)
        team = class_names[predicted.item()]
    return team

for image_name in os.listdir(test_dir):
    image_path = os.path.join(test_dir, image_name)
    if os.path.isfile(image_path):
        predicted_team = predict_image(image_path, model, transform)
        print(f'Image {image_name}: The player belongs to {predicted_team}')
